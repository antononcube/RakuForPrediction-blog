# %% [markdown]
# # Generating random Hamiltonian cycles
#
# See the [post at Mathematica.StackExchange](https://mathematica.stackexchange.com/q/312405/34008)

# %% [markdown]
# ----
#
# ## Setup

# %%
#%javascript
require.config({
     paths: {
     d3: 'https://d3js.org/d3.v7.min'
}});

require(['d3'], function(d3) {
     console.log(d3);
});

# %%
#%js
js-d3-list-line-plot(10.rand xx 30, background => 'none')

# %%
my $title-color = 'Ivory';
my $stroke-color = 'Ivory';
my $tooltip-color = 'LightBlue';
my $tooltip-background-color = 'none';
my $background = '1F1F1F';
my $color-scheme = 'schemeTableau10';
my $edge-thickness = 3;
my $vertex-size = 3;
my $vertex-label-color = 'Ivory';
my $mmd-theme = q:to/END/;
%%{
  init: {
    'theme': 'forest',
    'themeVariables': {
      'lineColor': 'Ivory'
    }
  }
}%%
END
my %force = charge => {strength => -30, iterations => 4}, collision => {radius => 20, iterations => 4}, link => {distance => 20};
# Out:
# {charge => {iterations => 4, strength => -30}, collision => {iterations => 4, radius => 20}, link => {distance => 20}}

# %% [markdown]
# ----
#
# ## Question

# %% [markdown]
# I need random Hamiltonian cycles in directed graphs. I guess for me it would be OK to mean by that choosing uniformly randomly from the set of all Hamiltonian cycles. `FindHamiltonianCycle` gives the same cycle every time, while, say,
#
# ```
# RandomChoice[FindHamiltonianCycle[CompleteGraph[n, DirectedEdges->True], All]]
# ```
# only works up to $n=11$ or so.
#
# Is there a way to do it for large $n$?

# %% [markdown]
# ------
#
# ## Comments

# %% [markdown]
# The so called Angluin-Valiant algorithm for finding Hamiltonian cycles is probabilistic, so it might produce the desired random cycles. –
# Anton Antonov
#  Commented yesterday

# %% [markdown]
# @AntonAntonov Sounds promising! Do you know whether Mathematica uses this algorithm in some form, or one would need to implement it from scratch? –
# მამუკა ჯიბლაძე

# %% [markdown]
# @მამუკაჯიბლაძე I have implemented that algorithm in Raku. I am not sure did I make a WL prototype first or not. (I will check later today/tonight.) But, I think it is a good idea to have that algorithm implemented in WL in a paclet or as a WFR entry. –
# Anton Antonov

# %% [markdown]
# @AntonAntonov Great! If you have any additional information please comment here. I mean, basically do I have to delve into Raku or not –
# მამუკა ჯიბლაძე

# %% [markdown]
# @მამუკაჯიბლაძე No, I do not advice to delve in Raku. :) But, maybe, it is a good idea for this question to try out the random Hamiltonian paths derivation with Raku first. If you are really curious, see [this presentation fragment](https://www.youtube.com/watch?v=fwQrQyWC7R0&t=410s).

# %% [markdown]
# -----
#
# ## Using standard algorithms

# %%
my $g = Graph::Complete(10).directed-graph
# Out:
# Graph(vertexes => 10, edges => 90, directed => True)

# %%
my @paths = $g.find-hamiltonian-path($g.vertex-list.pick, Whatever, method => Whatever, warendorfs-rule => rand > 0.5) xx 160;
@paths = @paths.unique(as => {.join('-')} ).sort;

.say for @paths
# Out:
# [1 6 2 5 9 10 8 4 7 3]
# [10 8 1 6 2 5 9 7 4 3]
# [2 5 9 10 8 1 6 7 4 3]
# [3 1 6 2 5 9 10 8 4 7]
# [4 5 9 10 8 1 6 2 3 7]
# [5 9 10 8 1 6 2 4 7 3]
# [6 2 5 9 10 8 1 7 4 3]
# [7 1 6 2 5 9 10 8 4 3]
# [8 1 6 2 5 9 10 7 4 3]
# [9 5 3 1 6 2 4 10 8 7]

# %%
#% html
my %opts = 
    node-width => 0.1, node-fill-color => 'SlateBlue', node-height => 0.1, node-font-size => 6, 
    edge-thickness => 0.4, arrow-size => 0.3,
    :7font-size,
    engine => 'neato', size => (3, 3), :svg;

@paths.map({
    my @highlight = $_.rotor(2 => -1).map({ $_.head => $_.tail });
    $g.dot(:@highlight, |%opts, graph-label => $_.gist)
}).join("\n")
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20241206.2353)
#  -->
# <!-- Pages: 1 -->
# <svg width="186pt" height="216pt"
#  viewBox="0.00 0.00 186.19 216.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.64218 1.64218) rotate(0) translate(4 127.53)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-127.53 109.38,-127.53 109.38,4 -4,4"/>
# <text text-anchor="middle" x="52.69" y="-112.88" font-family="Times,serif" font-size="7.00" fill="White">[1 6 2 5 9 10 8 4 7 3]</text>
# <!-- 1 -->
# <g id="node1" class="node">
# <title>1</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="4" cy="-54.73" rx="3.6" ry="3.6"/>
# <text text-anchor="middle" x="4" y="-52.78" font-family="Times,serif" font-size="6.00" fill="White">1</text>
# </g>
# <!-- 10 -->
# <g id="node2" class="node">
# <title>10</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="97.16" cy="-70.34" rx="3.6" ry="3.6"/>
# <text text-anchor="middle" x="97.16" y="-68.39" font-family="Times,serif" font-size="6.00" fill="White">10</text>
# </g>
# <!-- 1&#45;&gt;10 -->
# <g id="edge53" class="edge">
# <title>1&#45;&gt;10</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M6.67,-57.84C19.19,-65.2 72.06,-74.36 90.67,-72.81"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="90.48,-73.9 93.31,-72.44 90.19,-71.82 90.48,-73.9"/>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="43.35" cy="-5.56" rx="3.6" ry="3.6"/>
# <text text-anchor="middle" x="43.35" y="-3.61" font-family="Times,serif" font-size="6.00" fill="White">2</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge57" class="edge">
# <title>1&#45;&gt;2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M8,-54.46C17.54,-49.97 37.69,-25.4 42.92,-12.68"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="43.86,-13.18 43.79,-10.01 41.87,-12.53 43.86,-13.18"/>
# </g>
# <!-- 3 -->
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="44.34" cy="-100.74" rx="3.6" ry="3.6"/>
# <text text-anchor="middle" x="44.34" y="-98.79" font-family="Times,serif" font-size="6.00" fill="White">3</text>
# </g>
# <!-- 1&#45;&gt;3 -->
# <g id="edge51" class="edge">
# <title>1&#45;&gt;3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M3.51,-58.65C6.09,-68.63 26.16,-92.1 37.52,-99.2"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="36.79,-100 39.93,-100.46 37.76,-98.14 36.79,-100"/>
# </g>
# <!-- 4 -->
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="75.83" cy="-94.39" rx="3.6" ry="3.6"/>
# <text text-anchor="middle" x="75.83" y="-92.44" font-family="Times,serif" font-size="6.00" fill="White">4</text>
# </g>
# <!-- 1&#45;&gt;4 -->
# <g id="edge52" class="edge">
# <title>1&#45;&gt;4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M5.12,-58.35C12.8,-68.41 52.21,-90.59 68.73,-94.74"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="68.33,-95.73 71.47,-95.25 68.71,-93.67 68.33,-95.73"/>
# </g>
# <!-- 5 -->
# <g id="node6" class="node">
# <title>5</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="16.95" cy="-84.27" rx="3.6" ry="3.6"/>
# <text text-anchor="middle" x="16.95" y="-82.32" font-family="Times,serif" font-size="6.00" fill="White">5</text>
# </g>
# <!-- 1&#45;&gt;5 -->
# <g id="edge54" class="edge">
# <title>1&#45;&gt;5</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M1.71,-57.63C0,-63.58 4.85,-76.13 10.35,-81.75"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="9.59,-82.49 12.6,-83.52 10.89,-80.84 9.59,-82.49"/>
# </g>
# <!-- 6 -->
# <g id="node7" class="node">
# <title>6</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="14.68" cy="-23.24" rx="3.6" ry="3.6"/>
# <text text-anchor="middle" x="14.68" y="-21.29" font-family="Times,serif" font-size="6.00" fill="White">6</text>
# </g>
# <!-- 1&#45;&gt;6 -->
# <g id="edge89" class="edge">
# <title>1&#45;&gt;6</title>
# <path fill="none" stroke="DarkOrange" stroke-width="0.4" d="M7.67,-54.08C12.99,-50.7 18,-37.77 17.8,-29.7"/>
# <polygon fill="DarkOrange" stroke="DarkOrange" stroke-width="0.4" points="18.85,-29.59 17.36,-26.79 16.77,-29.91 18.85,-29.59"/>
# </g>
# <!-- 7 -->
# <g id="node8" class="node">
# <title>7</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="97.82" cy="-37.5" rx="3.6" ry="3.6"/>
# <text text-anchor="middle" x="97.82" y="-35.55" font-family="Times,serif" font-size="6.00" fill="White">7</text>
# </g>
# <!-- 1&#45;&gt;7 -->
# <g id="edge50" class="edge">
# <title>1&#45;&gt;7</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M7.15,-56.66C20.85,-59.56 74.98,-49.99 92.41,-42.09"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="92.67,-43.14 94.85,-40.82 91.7,-41.28 92.67,-43.14"/>
# </g>
# <!-- 8 -->
# <g id="node9" class="node">
# <title>8</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="52.46" cy="-50.39" rx="3.6" ry="3.6"/>
# <text text-anchor="middle" x="52.46" y="-48.44" font-family="Times,serif" font-size="6.00" fill="White">8</text>
# </g>
# <!-- 1&#45;&gt;8 -->
# <g id="edge56" class="edge">
# <title>1&#45;&gt;8</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M6.62,-57.62C14.34,-61.29 37.1,-59.71 47.35,-55.34"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="47.63,-56.39 49.78,-54.05 46.64,-54.54 47.63,-56.39"/>
# </g>
# <!-- 9 -->
# <g id="node10" class="node">
# <title>9</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="76.8" cy="-11.43" rx="3.6" ry="3.6"/>
# <text text-anchor="middle" x="76.8" y="-9.48" font-family="Times,serif" font-size="6.00" fill="White">9</text>
# </g>
# <!-- 1&#45;&gt;9 -->
# <g id="edge55" class="edge">
# <title>1&#45;&gt;9</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M7.77,-55.55C20.65,-53.82 60.96,-30.27 73.35,-17.83"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="74.06,-18.62 75.26,-15.67 72.48,-17.23 74.06,-18.62"/>
# </g>
# <!-- 10&#45;&gt;1 -->
# <g id="edge22" class="edge">
# <title>10&#45;&gt;1</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M94.49,-67.23C81.97,-59.88 29.1,-50.72 10.49,-52.26"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="10.68,-51.17 7.85,-52.63 10.97,-53.25 10.68,-51.17"/>
# </g>
# <!-- 10&#45;&gt;2 -->
# <g id="edge18" class="edge">
# <title>10&#45;&gt;2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M97.39,-66.51C93.71,-54.11 64.34,-18.16 50.18,-7.94"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="50.86,-7.12 47.76,-6.41 49.74,-8.9 50.86,-7.12"/>
# </g>
# <!-- 10&#45;&gt;3 -->
# <g id="edge24" class="edge">
# <title>10&#45;&gt;3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M93.41,-69.09C83.07,-69.64 55.85,-84.9 46.94,-94.61"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="46.5,-93.47 45.46,-96.47 48.15,-94.77 46.5,-93.47"/>
# </g>
# <!-- 10&#45;&gt;4 -->
# <g id="edge21" class="edge">
# <title>10&#45;&gt;4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M93.57,-69.47C87.46,-70.4 78.13,-80.03 75.35,-87.35"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="74.36,-86.96 74.69,-90.12 76.4,-87.45 74.36,-86.96"/>
# </g>
# <!-- 10&#45;&gt;5 -->
# <g id="edge23" class="edge">
# <title>10&#45;&gt;5</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M94.04,-68.22C81.85,-65.16 37.57,-72.47 22.21,-79.56"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="0.4" points="21.93,-78.52 19.79,-80.87 22.93,-80.37 21.93,-78.52"/>
# </g>
# <!-- 10&#45;&gt;6 -->
# <g id="edge20" class="edge">
# <title>10&#45;&gt;6</title>
# <path fill="none" stroke="SteelBlue" stroke-width="0.4" d="M96,-66.85C87.45,-55.82 40.1,-28.37 21.75,-23.21"/>
# <polygon fill="SteelBlue" stroke="S

# %% [markdown]
# ----
#
# ## Using Angluin-Valiant algorithm
#
# ... and D3.js graph plots.

# %% [markdown]
# **Remark:** The Angluin-Valiant algorithm works only for undirected graphs. (Graph's undirectedness is a fundamental assumption for the algorithm.)

# %%
my $g = Graph::Complete(10)
# Out:
# Graph(vertexes => 10, edges => 45, directed => False)

# %%
my @paths = $g.find-hamiltonian-path($g.vertex-list.pick, Whatever, method => 'random', pick => 'max-degree') xx 16;

.say for @paths
# Out:
# [3 5 2 1 8 10 4 7 9 6]
# [10 8 7 6 9 3 1 2 4 5]
# [6 5 8 4 7 9 1 10 2 3]
# [2 6 8 1 10 7 3 4 9 5]
# [3 2 9 5 6 7 1 10 4 8]
# [10 4 8 1 5 3 2 7 6 9]
# [2 9 10 8 1 5 3 4 7 6]
# [1 2 7 6 10 8 9 5 3 4]
# [2 9 10 5 1 6 4 3 8 7]
# [9 7 5 8 6 1 3 10 4 2]
# [7 2 1 6 10 4 8 3 5 9]
# [6 9 2 10 8 7 1 3 5 4]
# [9 10 5 2 8 1 6 7 3 4]
# [1 10 2 9 7 3 8 4 6 5]
# [3 8 1 10 2 7 9 5 4 6]
# [8 4 6 2 5 7 10 9 1 3]

# %%
#% js
my %force = charge => {strength => -2000, iterations => 4}, collision => {radius => 20, iterations => 4}, link => {distance => 20};
@paths.map({
    my @highlight = $_.rotor(2 => -1).map({ $_.head => $_.tail });
    js-d3-graph-plot($g.edges,
        directed => $g.directed,
        :350width,
        :400height,
        :@highlight, 
        :$background, 
        :$vertex-label-color, 
        arrowhead-size => 0.2,
        :$title-color, 
        title => $_.gist,
        :%force)
}).join("\n")
