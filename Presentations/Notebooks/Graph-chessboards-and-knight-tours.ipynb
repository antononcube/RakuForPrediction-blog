# %% [markdown]
# # Chessboards and knight's tours in Raku
#
# <span style="font-size: 16pt; font-style: italic; font-weight: bold">...via graph functionalities</span>
#
# Anton Antonov
# [RakuForPrediction at WordPress](https://rakuforprediction.wordpress.com)
# [RakuForPrediction-book at GitHub](https://github.com/antononcube/RakuForPrediction-book)
# November 2024

# %% [markdown]
# -----
#
# ## Introduction

# %% [markdown]
# - Two ways of plotting chessboards
# - [Knight's tour](https://en.wikipedia.org/wiki/Knight%27s_tour) graphs
# - [Hamiltonian paths](https://en.wikipedia.org/wiki/Hamiltonian_path)

# %% [markdown]
# ------
#
# ## Setup

# %% [markdown]
# Here are loaded the packages used in the rest of notebook:

# %%
use Graph;

use Graph::Circulant;
use Graph::Complete;
use Graph::CompleteKaryTree;
use Graph::Cycle;
use Graph::Grid;
use Graph::HexagonalGrid;
use Graph::Hypercube;
use Graph::KnightTour;
use Graph::Nested;
use Graph::Path;
use Graph::Petersen;
use Graph::Star;
use Graph::TriangularGrid;
use Graph::Wheel;

use Graph::Distribution;
use Graph::Random;

use Data::Reshapers;
use Data::Summarizers;
use Data::Generators;
use Data::TypeSystem;
use Data::Translators;
use Data::Geographics;

use Math::DistanceFunctions;
use Math::Nearest;
use Text::Levenshtein::Damerau;

use Hash::Merge;
use FunctionalParsers;
use FunctionalParsers::EBNF;
use EBNF::Grammar;
use Graphviz::DOT::Grammar;

use JavaScript::D3;
use WWW::MermaidInk;

use paths;

# %% [markdown]
# ### JavaScript

# %% [markdown]
# Here we prepare the notebook to visualize with JavaScript:

# %%
#% javascript
require.config({
     paths: {
     d3: 'https://d3js.org/d3.v7.min'
}});

require(['d3'], function(d3) {
     console.log(d3);
});

# %% [markdown]
# Verification:

# %%
#% js
js-d3-list-line-plot(10.rand xx 40, background => 'none', stroke-width => 2)

# %% [markdown]
# Here we set a collection of visualization variables:

# %%
my $title-color = 'Ivory';
my $tick-labels-color = 'Ivory';
my $stroke-color = 'SlateGray';
my $tooltip-color = 'LightBlue';
my $tooltip-background-color = 'none';
my $background = '#1F1F1F';
my $color-scheme = 'schemeTableau10';
my $edge-thickness = 3;
my $vertex-size = 6;
my $engine = 'neato';
my $mmd-theme = q:to/END/;
%%{
  init: {
    'theme': 'forest',
    'themeVariables': {
      'lineColor': 'Ivory'
    }
  }
}%%
END
my %force = collision => {iterations => 0, radius => 10},link => {distance => 180};
my %force2 = charge => {strength => -30, iterations => 4}, collision => {radius => 50, iterations => 4}, link => {distance => 30};

my %opts = :$background, :$title-color, :$edge-thickness, :$vertex-size;
# Out:
# {background => #1F1F1F, edge-thickness => 3, title-color => Ivory, vertex-size => 6}

# %% [markdown]
# ------
#
# ## Chessboards

# %% [markdown]
# Make a chessboard SVG plot using a grid graph:

# %%
#%html
my $gg = Graph::Grid.new(4, 6);

# Leveraging the grid graphs a bipartite
my %highlight = <DimGray LightGray> Z=> $gg.bipartite-coloring.classify(*.value).nodemap(*».key).values;


# DOT language spec
my $preamble = q:to/END/;
fontcolor = "Ivory";
fontsize = "16";
labelloc = "t";
label = "Chessboard by DOT";
graph [size="8,16!"];

bgcolor="#1F1F1F";
node [style=filled, label="", opacity=0.3, fixedsize=true, shape=square, color="Black", fillcolor="SlateBlue", penwidth=1, fontsize=4, fontcolor="White", labelloc=c, width=0.98, height=0.3];
edge [style=invis, color="SteelBlue", penwidth=0.6];
END

# To be reused for overlaying tour paths
my $dot = $gg.dot(:$preamble, :%highlight, :!node-labels).lines[1..*-2].join("\n");

# Rendering of the DOT spec
$gg.dot(:$preamble, :%highlight, :!node-labels, engine=>'neato'):svg;
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="422pt"
#  viewBox="0.00 0.00 576.00 422.01" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.31339 1.31339) rotate(0) translate(4 317.31)">
# <polygon fill="#1f1f1f" stroke="none" points="-4,4 -4,-317.31 434.56,-317.31 434.56,4 -4,4"/>
# <text text-anchor="middle" x="215.28" y="-294.11" font-family="Times,serif" font-size="16.00" fill="Ivory">Chessboard by DOT</text>
# <!-- 0_2 -->
# <g id="node1" class="node">
# <title>0_2</title>
# <polygon fill="DimGray" stroke="DimGray" points="214.56,-70.56 144,-70.56 144,0 214.56,0 214.56,-70.56"/>
# </g>
# <!-- 0_3 -->
# <g id="node12" class="node">
# <title>0_3</title>
# <polygon fill="LightGray" stroke="LightGray" points="286.56,-70.56 216,-70.56 216,0 286.56,0 286.56,-70.56"/>
# </g>
# <!-- 0_2&#45;&#45;0_3 -->
# <!-- 1_2 -->
# <g id="node20" class="node">
# <title>1_2</title>
# <polygon fill="LightGray" stroke="LightGray" points="214.56,-142.56 144,-142.56 144,-72 214.56,-72 214.56,-142.56"/>
# </g>
# <!-- 0_2&#45;&#45;1_2 -->
# <!-- 2_4 -->
# <g id="node2" class="node">
# <title>2_4</title>
# <polygon fill="DimGray" stroke="DimGray" points="358.56,-214.56 288,-214.56 288,-144 358.56,-144 358.56,-214.56"/>
# </g>
# <!-- 3_4 -->
# <g id="node17" class="node">
# <title>3_4</title>
# <polygon fill="LightGray" stroke="LightGray" points="358.56,-286.56 288,-286.56 288,-216 358.56,-216 358.56,-286.56"/>
# </g>
# <!-- 2_4&#45;&#45;3_4 -->
# <!-- 2_5 -->
# <g id="node24" class="node">
# <title>2_5</title>
# <polygon fill="LightGray" stroke="LightGray" points="430.56,-214.56 360,-214.56 360,-144 430.56,-144 430.56,-214.56"/>
# </g>
# <!-- 2_4&#45;&#45;2_5 -->
# <!-- 0_4 -->
# <g id="node3" class="node">
# <title>0_4</title>
# <polygon fill="DimGray" stroke="DimGray" points="358.56,-70.56 288,-70.56 288,0 358.56,0 358.56,-70.56"/>
# </g>
# <!-- 0_5 -->
# <g id="node9" class="node">
# <title>0_5</title>
# <polygon fill="LightGray" stroke="LightGray" points="430.56,-70.56 360,-70.56 360,0 430.56,0 430.56,-70.56"/>
# </g>
# <!-- 0_4&#45;&#45;0_5 -->
# <!-- 1_4 -->
# <g id="node14" class="node">
# <title>1_4</title>
# <polygon fill="LightGray" stroke="LightGray" points="358.56,-142.56 288,-142.56 288,-72 358.56,-72 358.56,-142.56"/>
# </g>
# <!-- 0_4&#45;&#45;1_4 -->
# <!-- 2_2 -->
# <g id="node4" class="node">
# <title>2_2</title>
# <polygon fill="DimGray" stroke="DimGray" points="214.56,-214.56 144,-214.56 144,-144 214.56,-144 214.56,-214.56"/>
# </g>
# <!-- 3_2 -->
# <g id="node6" class="node">
# <title>3_2</title>
# <polygon fill="LightGray" stroke="LightGray" points="214.56,-286.56 144,-286.56 144,-216 214.56,-216 214.56,-286.56"/>
# </g>
# <!-- 2_2&#45;&#45;3_2 -->
# <!-- 2_3 -->
# <g id="node10" class="node">
# <title>2_3</title>
# <polygon fill="LightGray" stroke="LightGray" points="286.56,-214.56 216,-214.56 216,-144 286.56,-144 286.56,-214.56"/>
# </g>
# <!-- 2_2&#45;&#45;2_3 -->
# <!-- 1_5 -->
# <g id="node5" class="node">
# <title>1_5</title>
# <polygon fill="DimGray" stroke="DimGray" points="430.56,-142.56 360,-142.56 360,-72 430.56,-72 430.56,-142.56"/>
# </g>
# <!-- 1_5&#45;&#45;2_5 -->
# <!-- 3_3 -->
# <g id="node23" class="node">
# <title>3_3</title>
# <polygon fill="DimGray" stroke="DimGray" points="286.56,-286.56 216,-286.56 216,-216 286.56,-216 286.56,-286.56"/>
# </g>
# <!-- 3_2&#45;&#45;3_3 -->
# <!-- 3_1 -->
# <g id="node7" class="node">
# <title>3_1</title>
# <polygon fill="DimGray" stroke="DimGray" points="142.56,-286.56 72,-286.56 72,-216 142.56,-216 142.56,-286.56"/>
# </g>
# <!-- 3_1&#45;&#45;3_2 -->
# <!-- 2_1 -->
# <g id="node8" class="node">
# <title>2_1</title>
# <polygon fill="LightGray" stroke="LightGray" points="142.56,-214.56 72,-214.56 72,-144 142.56,-144 142.56,-214.56"/>
# </g>
# <!-- 2_1&#45;&#45;2_2 -->
# <!-- 2_1&#45;&#45;3_1 -->
# <!-- 0_5&#45;&#45;1_5 -->
# <!-- 2_3&#45;&#45;2_4 -->
# <!-- 2_3&#45;&#45;3_3 -->
# <!-- 3_0 -->
# <g id="node11" class="node">
# <title>3_0</title>
# <polygon fill="LightGray" stroke="LightGray" points="70.56,-286.56 0,-286.56 0,-216 70.56,-216 70.56,-286.56"/>
# </g>
# <!-- 3_0&#45;&#45;3_1 -->
# <!-- 0_3&#45;&#45;0_4 -->
# <!-- 1_3 -->
# <g id="node21" class="node">
# <title>1_3</title>
# <polygon fill="DimGray" stroke="DimGray" points="286.56,-142.56 216,-142.56 216,-72 286.56,-72 286.56,-142.56"/>
# </g>
# <!-- 0_3&#45;&#45;1_3 -->
# <!-- 0_0 -->
# <g id="node13" class="node">
# <title>0_0</title>
# <polygon fill="DimGray" stroke="DimGray" points="70.56,-70.56 0,-70.56 0,0 70.56,0 70.56,-70.56"/>
# </g>
# <!-- 0_1 -->
# <g id="node16" class="node">
# <title>0_1</title>
# <polygon fill="LightGray" stroke="LightGray" points="142.56,-70.56 72,-70.56 72,0 142.56,0 142.56,-70.56"/>
# </g>
# <!-- 0_0&#45;&#45;0_1 -->
# <!-- 1_0 -->
# <g id="node19" class="node">
# <title>1_0</title>
# <polygon fill="LightGray" stroke="LightGray" points="70.56,-142.56 0,-142.56 0,-72 70.56,-72 70.56,-142.56"/>
# </g>
# <!-- 0_0&#45;&#45;1_0 -->
# <!-- 1_4&#45;&#45;2_4 -->
# <!-- 1_4&#45;&#45;1_5 -->
# <!-- 3_5 -->
# <g id="node15" class="node">
# <title>3_5</title>
# <polygon fill="DimGray" stroke="DimGray" points="430.56,-286.56 360,-286.56 360,-216 430.56,-216 430.56,-286.56"/>
# </g>
# <!-- 0_1&#45;&#45;0_2 -->
# <!-- 1_1 -->
# <g id="node22" class="node">
# <title>1_1</title>
# <polygon fill="DimGray" stroke="DimGray" points="142.56,-142.56 72,-142.56 72,-72 142.56,-72 142.56,-142.56"/>
# </g>
# <!-- 0_1&#45;&#45;1_1 -->
# <!-- 3_4&#45;&#45;3_5 -->
# <!-- 2_0 -->
# <g id="node18" class="node">
# <title>2_0</title>
# <polygon fill="DimGray" stroke="DimGray" points="70.56,-214.56 0,-214.56 0,-144 70.56,-144 70.56,-214.56"/>
# </g>
# <!-- 2_0&#45;&#45;2_1 -->
# <!-- 2_0&#45;&#45;3_0 -->
# <!-- 1_0&#45;&#45;2_0 -->
# <!-- 1_0&#45;&#45;1_1 -->
# <!-- 1_2&#45;&#45;2_2 -->
# <!-- 1_2&#45;&#45;1_3 -->
# <!-- 1_3&#45;&#45;2_3 -->
# <!-- 1_3&#45;&#45;1_4 -->
# <!-- 1_1&#45;&#45;2_1 -->
# <!-- 1_1&#45;&#45;1_2 -->
# <!-- 3_3&#45;&#45;3_4 -->
# <!-- 2_5&#45;&#45;3_5 -->
# </g>
# </svg>

# %% [markdown]
# Here is another way to make a chessboard (not used here because it is hard to do the combined board-tour plot below):

# %%
#% js
js-d3-chessboard('8/8/8/8/8/8/8/8', :$background, :$tick-labels-color, :$title-color, color-palette => 'Greys')

# %% [markdown]
# --------
#
# ## Knight's tour over a chessboard

# %% [markdown]
# Make a Knight's tour graph:

# %%
my $gkt = Graph::KnightTour.new(4, 6, prefix => 'kt');
# Out:
# Graph(vertexes => 24, edges => 44, directed => False)

# %% [markdown]
# Show the corresponding Graphviz DOT plot:

# %%
#% html
$gkt.dot(:$engine, :$background, vertex-shape => 'ellipse', vertex-width => 0.6):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="411pt" height="246pt"
#  viewBox="0.00 0.00 411.20 245.60" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 241.6)">
# <polygon fill="#1f1f1f" stroke="none" points="-4,4 -4,-241.6 407.2,-241.6 407.2,4 -4,4"/>
# <!-- kt3_1 -->
# <g id="node1" class="node">
# <title>kt3_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="237.6" cy="-82.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="237.6" y="-78.52" font-family="Times,serif" font-size="12.00" fill="White">kt3_1</text>
# </g>
# <!-- kt5_2 -->
# <g id="node9" class="node">
# <title>kt5_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="381.6" cy="-154.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="381.6" y="-150.52" font-family="Times,serif" font-size="12.00" fill="White">kt5_2</text>
# </g>
# <!-- kt3_1&#45;&#45;kt5_2 -->
# <g id="edge7" class="edge">
# <title>kt3_1&#45;&#45;kt5_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M253.28,-90.64C280.98,-104.49 338.25,-133.12 365.93,-146.97"/>
# </g>
# <!-- kt4_3 -->
# <g id="node13" class="node">
# <title>kt4_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="309.6" cy="-226.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="309.6" y="-222.52" font-family="Times,serif" font-size="12.00" fill="White">kt4_3</text>
# </g>
# <!-- kt3_1&#45;&#45;kt4_3 -->
# <g id="edge6" class="edge">
# <title>kt3_1&#45;&#45;kt4_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M243.01,-93.62C256.42,-120.44 291.05,-189.71 304.32,-216.24"/>
# </g>
# <!-- kt5_0 -->
# <g id="node24" class="node">
# <title>kt5_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="381.6" cy="-10.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="381.6" y="-6.52" font-family="Times,serif" font-size="12.00" fill="White">kt5_0</text>
# </g>
# <!-- kt3_1&#45;&#45;kt5_0 -->
# <g id="edge10" class="edge">
# <title>kt3_1&#45;&#45;kt5_0</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M253.28,-74.96C280.98,-61.11 338.25,-32.48 365.93,-18.63"/>
# </g>
# <!-- kt0_1 -->
# <g id="node2" class="node">
# <title>kt0_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="21.6" cy="-82.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="21.6" y="-78.52" font-family="Times,serif" font-size="12.00" fill="White">kt0_1</text>
# </g>
# <!-- kt2_0 -->
# <g id="node10" class="node">
# <title>kt2_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="165.6" cy="-10.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="165.6" y="-6.52" font-family="Times,serif" font-size="12.00" fill="White">kt2_0</text>
# </g>
# <!-- kt0_1&#45;&#45;kt2_0 -->
# <g id="edge20" class="edge">
# <title>kt0_1&#45;&#45;kt2_0</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M37.28,-74.96C64.98,-61.11 122.25,-32.48 149.93,-18.63"/>
# </g>
# <!-- kt2_2 -->
# <g id="node11" class="node">
# <title>kt2_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="165.6" cy="-154.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="165.6" y="-150.52" font-family="Times,serif" font-size="12.00" fill="White">kt2_2</text>
# </g>
# <!-- kt0_1&#45;&#45;kt2_2 -->
# <g id="edge26" class="edge">
# <title>kt0_1&#45;&#45;kt2_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M37.28,-90.64C64.98,-104.49 122.25,-133.12 149.93,-146.97"/>
# </g>
# <!-- kt1_3 -->
# <g id="node18" class="node">
# <title>kt1_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="93.6" cy="-226.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="93.6" y="-222.52" font-family="Times,serif" font-size="12.00" fill="White">kt1_3</text>
# </g>
# <!-- kt0_1&#45;&#45;kt1_3 -->
# <g id="edge27" class="edge">
# <title>kt0_1&#45;&#45;kt1_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M27.01,-93.62C40.42,-120.44 75.05,-189.71 88.32,-216.24"/>
# </g>
# <!-- kt1_1 -->
# <g id="node3" class="node">
# <title>kt1_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="93.6" cy="-82.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="93.6" y="-78.52" font-family="Times,serif" font-size="12.00" fill="White">kt1_1</text>
# </g>
# <!-- kt2_3 -->
# <g id="node14" class="node">
# <title>kt2_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="165.6" cy="-226.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="165.6" y="-222.52" font-family="Times,serif" font-size="12.00" fill="White">kt2_3</text>
# </g>
# <!-- kt1_1&#45;&#45;kt2_3 -->
# <g id="edge15" class="edge">
# <title>kt1_1&#45;&#45;kt2_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M99.01,-93.62C112.42,-120.44 147.05,-189.71 160.32,-216.24"/>
# </g>
# <!-- kt3_2 -->
# <g id="node15" class="node">
# <title>kt3_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="237.6" cy="-154.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="237.6" y="-150.52" font-family="Times,serif" font-size="12.00" fill="White">kt3_2</text>
# </g>
# <!-- kt1_1&#45;&#45;kt3_2 -->
# <g id="edge16" class="edge">
# <title>kt1_1&#45;&#45;kt3_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M109.28,-90.64C136.98,-104.49 194.25,-133.12 221.93,-146.97"/>
# </g>
# <!-- kt3_0 -->
# <g id="node20" class="node">
# <title>kt3_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="237.6" cy="-10.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="237.6" y="-6.52" font-family="Times,serif" font-size="12.00" fill="White">kt3_0</text>
# </g>
# <!-- kt1_1&#45;&#45;kt3_0 -->
# <g id="edge14" class="edge">
# <title>kt1_1&#45;&#45;kt3_0</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M109.28,-74.96C136.98,-61.11 194.25,-32.48 221.93,-18.63"/>
# </g>
# <!-- kt1_0 -->
# <g id="node4" class="node">
# <title>kt1_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="93.6" cy="-10.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="93.6" y="-6.52" font-family="Times,serif" font-size="12.00" fill="White">kt1_0</text>
# </g>
# <!-- kt1_0&#45;&#45;kt3_1 -->
# <g id="edge44" class="edge">
# <title>kt1_0&#45;&#45;kt3_1</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M109.28,-18.64C136.98,-32.49 194.25,-61.12 221.93,-74.97"/>
# </g>
# <!-- kt1_0&#45;&#45;kt2_2 -->
# <g id="edge42" class="edge">
# <title>kt1_0&#45;&#45;kt2_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M99.01,-21.62C112.42,-48.44 147.05,-117.71 160.32,-144.24"/>
# </g>
# <!-- kt3_3 -->
# <g id="node5" class="node">
# <title>kt3_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="237.6" cy="-226.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="237.6" y="-222.52" font-family="Times,serif" font-size="12.00" fill="White">kt3_3</text>
# </g>
# <!-- kt3_3&#45;&#45;kt5_2 -->
# <g id="edge39" class="edge">
# <title>kt3_3&#45;&#45;kt5_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M253.28,-218.96C280.98,-205.11 338.25,-176.48 365.93,-162.63"/>
# </g>
# <!-- kt4_1 -->
# <g id="node22" class="node">
# <title>kt4_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="309.6" cy="-82.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="309.6" y="-78.52" font-family="Times,serif" font-size="12.00" fill="White">kt4_1</text>
# </g>
# <!-- kt3_3&#45;&#45;kt4_1 -->
# <g id="edge36" class="edge">
# <title>kt3_3&#45;&#45;kt4_1</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M243.01,-215.98C256.42,-189.16 291.05,-119.89 304.32,-93.36"/>
# </g>
# <!-- kt4_0 -->
# <g id="node6" class="node">
# <title>kt4_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="309.6" cy="-10.8" rx="21.6" ry="10.8"/>
# <text text-anchor="middle" x="309.6" y="-6.52" font-family="Times,serif" font-size="12.00" fill="White">kt4_0</text>
# </g>
# <!-- kt4_0&#45;&#45;kt5_2 -->
# <g id="edge40" class="edge">
# <title>kt4_0&#45;&#45;kt5_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="2" d="M315.01,-21.62C328.42,-48.44 363.05,-117.71 376.32,-144.24"/>
# </g>
# <!-- kt5_3 -->
# <g id="node7

# %% [markdown]
# -----
#
# ## Hamiltonian path finding

# %% [markdown]
# - Finding a Hamiltonian path is NP-complete problem.
# - Hence, using algorithms that is fast, but do not always "work" can be desirable.

# %% [markdown]
# Two algorithms to consider:

# %% [markdown]
# - The backtracking algorithm with [Warnsdorf's rule](https://en.wikipedia.org/wiki/Knight%27s_tour#Warnsdorf's_rule)
# - Random (Angluin-Valiant) algorithm

# %% [markdown]
# Using (deterministic) backtracking algorithm to find a Hamiltonian path:

# %%
my $end = 'kt0_3'; #'kt0_3';# Whatever;
my @hpath = $gkt.find-hamiltonian-path('kt0_0', $end, method => 'backtracking', :warnsdorf-rule);
# Out:
# [kt0_0 kt1_2 kt2_0 kt0_1 kt1_3 kt3_2 kt5_3 kt4_1 kt3_3 kt5_2 kt4_0 kt2_1 kt0_2 kt1_0 kt2_2 kt3_0 kt5_1 kt4_3 kt3_1 kt5_0 kt4_2 kt2_3 kt1_1 kt0_3]

# %% [markdown]
# Using (random) Angluin-Valiant algorithm:

# %%
my @hpath = $gkt.find-hamiltonian-path('kt0_0', $end, method => 'random', pick => 'max-degree');
# Out:
# [kt0_0 kt2_1 kt1_3 kt0_1 kt2_0 kt1_2 kt3_3 kt4_1 kt5_3 kt3_2 kt4_0 kt5_2 kt3_1 kt5_0 kt4_2 kt3_0 kt5_1 kt4_3 kt2_2 kt1_0 kt0_2 kt2_3 kt1_1 kt0_3]

# %% [markdown]
# Show the found Hamiltonian Knight path on a chessboard:

# %%
#% html

# Reusing the "chessboard graph" DOT spec above.
my $preamble = [
    $dot.subst('--', '->', :g).subst('label="",').subst('Chessboard by DOT', "Knight's Hamiltonian path"),
    'node [shape=ellipse, fillcolor=Yellow, width=0.6, height=0.2, fixedsize=true, style=filled, color=Orange, fontsize=10, fontcolor=Black];',
    'edge [style=filled, width=103, color=Orange];',
].join("\n");

# Make a path graph from the found Hamiltonian path.
my $gp = Graph::Path.new(@hpath):directed;

# Set the graph vertex coordinates.
$gp.vertex-coordinates = $gkt.vertex-coordinates;

# Replace (rename) the path graph vertices to ordinals. 
# (In order to show the sequential order of the path.)
$gp .= vertex-replace((@hpath Z=> (^@hpath.elems)».Str).Hash); 

$gp.dot(:$preamble, engine=>'neato'):svg;
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="422pt"
#  viewBox="0.00 0.00 576.00 422.01" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.31339 1.31339) rotate(0) translate(4 317.31)">
# <polygon fill="#1f1f1f" stroke="none" points="-4,4 -4,-317.31 434.56,-317.31 434.56,4 -4,4"/>
# <text text-anchor="middle" x="215.28" y="-294.11" font-family="Times,serif" font-size="16.00" fill="Ivory">Knight&#39;s Hamiltonian path</text>
# <!-- 0_2 -->
# <g id="node1" class="node">
# <title>0_2</title>
# <polygon fill="DimGray" stroke="DimGray" points="214.56,-70.56 144,-70.56 144,0 214.56,0 214.56,-70.56"/>
# <text text-anchor="middle" x="179.28" y="-34.11" font-family="Times,serif" font-size="4.00" fill="White">0_2</text>
# </g>
# <!-- 0_3 -->
# <g id="node12" class="node">
# <title>0_3</title>
# <polygon fill="LightGray" stroke="LightGray" points="286.56,-70.56 216,-70.56 216,0 286.56,0 286.56,-70.56"/>
# <text text-anchor="middle" x="251.28" y="-34.11" font-family="Times,serif" font-size="4.00" fill="White">0_3</text>
# </g>
# <!-- 0_2&#45;&gt;0_3 -->
# <!-- 1_2 -->
# <g id="node20" class="node">
# <title>1_2</title>
# <polygon fill="LightGray" stroke="LightGray" points="214.56,-142.56 144,-142.56 144,-72 214.56,-72 214.56,-142.56"/>
# <text text-anchor="middle" x="179.28" y="-106.11" font-family="Times,serif" font-size="4.00" fill="White">1_2</text>
# </g>
# <!-- 0_2&#45;&gt;1_2 -->
# <!-- 2_4 -->
# <g id="node2" class="node">
# <title>2_4</title>
# <polygon fill="DimGray" stroke="DimGray" points="358.56,-214.56 288,-214.56 288,-144 358.56,-144 358.56,-214.56"/>
# <text text-anchor="middle" x="323.28" y="-178.11" font-family="Times,serif" font-size="4.00" fill="White">2_4</text>
# </g>
# <!-- 3_4 -->
# <g id="node17" class="node">
# <title>3_4</title>
# <polygon fill="LightGray" stroke="LightGray" points="358.56,-286.56 288,-286.56 288,-216 358.56,-216 358.56,-286.56"/>
# <text text-anchor="middle" x="323.28" y="-250.11" font-family="Times,serif" font-size="4.00" fill="White">3_4</text>
# </g>
# <!-- 2_4&#45;&gt;3_4 -->
# <!-- 2_5 -->
# <g id="node24" class="node">
# <title>2_5</title>
# <polygon fill="LightGray" stroke="LightGray" points="430.56,-214.56 360,-214.56 360,-144 430.56,-144 430.56,-214.56"/>
# <text text-anchor="middle" x="395.28" y="-178.11" font-family="Times,serif" font-size="4.00" fill="White">2_5</text>
# </g>
# <!-- 2_4&#45;&gt;2_5 -->
# <!-- 0_4 -->
# <g id="node3" class="node">
# <title>0_4</title>
# <polygon fill="DimGray" stroke="DimGray" points="358.56,-70.56 288,-70.56 288,0 358.56,0 358.56,-70.56"/>
# <text text-anchor="middle" x="323.28" y="-34.11" font-family="Times,serif" font-size="4.00" fill="White">0_4</text>
# </g>
# <!-- 0_5 -->
# <g id="node9" class="node">
# <title>0_5</title>
# <polygon fill="LightGray" stroke="LightGray" points="430.56,-70.56 360,-70.56 360,0 430.56,0 430.56,-70.56"/>
# <text text-anchor="middle" x="395.28" y="-34.11" font-family="Times,serif" font-size="4.00" fill="White">0_5</text>
# </g>
# <!-- 0_4&#45;&gt;0_5 -->
# <!-- 1_4 -->
# <g id="node14" class="node">
# <title>1_4</title>
# <polygon fill="LightGray" stroke="LightGray" points="358.56,-142.56 288,-142.56 288,-72 358.56,-72 358.56,-142.56"/>
# <text text-anchor="middle" x="323.28" y="-106.11" font-family="Times,serif" font-size="4.00" fill="White">1_4</text>
# </g>
# <!-- 0_4&#45;&gt;1_4 -->
# <!-- 2_2 -->
# <g id="node4" class="node">
# <title>2_2</title>
# <polygon fill="DimGray" stroke="DimGray" points="214.56,-214.56 144,-214.56 144,-144 214.56,-144 214.56,-214.56"/>
# <text text-anchor="middle" x="179.28" y="-178.11" font-family="Times,serif" font-size="4.00" fill="White">2_2</text>
# </g>
# <!-- 3_2 -->
# <g id="node6" class="node">
# <title>3_2</title>
# <polygon fill="LightGray" stroke="LightGray" points="214.56,-286.56 144,-286.56 144,-216 214.56,-216 214.56,-286.56"/>
# <text text-anchor="middle" x="179.28" y="-250.11" font-family="Times,serif" font-size="4.00" fill="White">3_2</text>
# </g>
# <!-- 2_2&#45;&gt;3_2 -->
# <!-- 2_3 -->
# <g id="node10" class="node">
# <title>2_3</title>
# <polygon fill="LightGray" stroke="LightGray" points="286.56,-214.56 216,-214.56 216,-144 286.56,-144 286.56,-214.56"/>
# <text text-anchor="middle" x="251.28" y="-178.11" font-family="Times,serif" font-size="4.00" fill="White">2_3</text>
# </g>
# <!-- 2_2&#45;&gt;2_3 -->
# <!-- 1_5 -->
# <g id="node5" class="node">
# <title>1_5</title>
# <polygon fill="DimGray" stroke="DimGray" points="430.56,-142.56 360,-142.56 360,-72 430.56,-72 430.56,-142.56"/>
# <text text-anchor="middle" x="395.28" y="-106.11" font-family="Times,serif" font-size="4.00" fill="White">1_5</text>
# </g>
# <!-- 1_5&#45;&gt;2_5 -->
# <!-- 3_3 -->
# <g id="node23" class="node">
# <title>3_3</title>
# <polygon fill="DimGray" stroke="DimGray" points="286.56,-286.56 216,-286.56 216,-216 286.56,-216 286.56,-286.56"/>
# <text text-anchor="middle" x="251.28" y="-250.11" font-family="Times,serif" font-size="4.00" fill="White">3_3</text>
# </g>
# <!-- 3_2&#45;&gt;3_3 -->
# <!-- 3_1 -->
# <g id="node7" class="node">
# <title>3_1</title>
# <polygon fill="DimGray" stroke="DimGray" points="142.56,-286.56 72,-286.56 72,-216 142.56,-216 142.56,-286.56"/>
# <text text-anchor="middle" x="107.28" y="-250.11" font-family="Times,serif" font-size="4.00" fill="White">3_1</text>
# </g>
# <!-- 3_1&#45;&gt;3_2 -->
# <!-- 2_1 -->
# <g id="node8" class="node">
# <title>2_1</title>
# <polygon fill="LightGray" stroke="LightGray" points="142.56,-214.56 72,-214.56 72,-144 142.56,-144 142.56,-214.56"/>
# <text text-anchor="middle" x="107.28" y="-178.11" font-family="Times,serif" font-size="4.00" fill="White">2_1</text>
# </g>
# <!-- 2_1&#45;&gt;2_2 -->
# <!-- 2_1&#45;&gt;3_1 -->
# <!-- 0_5&#45;&gt;1_5 -->
# <!-- 2_3&#45;&gt;2_4 -->
# <!-- 2_3&#45;&gt;3_3 -->
# <!-- 3_0 -->
# <g id="node11" class="node">
# <title>3_0</title>
# <polygon fill="LightGray" stroke="LightGray" points="70.56,-286.56 0,-286.56 0,-216 70.56,-216 70.56,-286.56"/>
# <text text-anchor="middle" x="35.28" y="-250.11" font-family="Times,serif" font-size="4.00" fill="White">3_0</text>
# </g>
# <!-- 3_0&#45;&gt;3_1 -->
# <!-- 0_3&#45;&gt;0_4 -->
# <!-- 1_3 -->
# <g id="node21" class="node">
# <title>1_3</title>
# <polygon fill="DimGray" stroke="DimGray" points="286.56,-142.56 216,-142.56 216,-72 286.56,-72 286.56,-142.56"/>
# <text text-anchor="middle" x="251.28" y="-106.11" font-family="Times,serif" font-size="4.00" fill="White">1_3</text>
# </g>
# <!-- 0_3&#45;&gt;1_3 -->
# <!-- 0_0 -->
# <g id="node13" class="node">
# <title>0_0</title>
# <polygon fill="DimGray" stroke="DimGray" points="70.56,-70.56 0,-70.56 0,0 70.56,0 70.56,-70.56"/>
# <text text-anchor="middle" x="35.28" y="-34.11" font-family="Times,serif" font-size="4.00" fill="White">0_0</text>
# </g>
# <!-- 0_1 -->
# <g id="node16" class="node">
# <title>0_1</title>
# <polygon fill="LightGray" stroke="LightGray" points="142.56,-70.56 72,-70.56 72,0 142.56,0 142.56,-70.56"/>
# <text text-anchor="middle" x="107.28" y="-34.11" font-family="Times,serif" font-size="4.00" fill="White">0_1</text>
# </g>
# <!-- 0_0&#45;&gt;0_1 -->
# <!-- 1_0 -->
# <g id="node19" class="node">
# <title>1_0</title>
# <polygon fill="LightGray" stroke="LightGray" points="70.56,-142.56 0,-142.56 0,-72 70.56,-72 70.56,-142.56"/>
# <text text-anchor="middle" x="35.28" y="-106.11" font-family="Times,serif" font-size="4.00" fill="White">1_0</text>
# </g>
# <!-- 0_0&#45;&gt;1_0 -->
# <!-- 1_4&#45;&gt;2_4 -->
# <!-- 1_4&#45;&gt;1_5 -->
# <!-- 3_5 -->
# <g id="node15" class="node">
# <title>3_5</title>
# <polygon fill="DimGray" stroke="DimGray" points="430.56,-286.56 360,-286.56 360,-216 430.56,-216 430.56,-286.56"/>
# <text text-anchor="middle" x="395.28" y="-250.11" font-family="Times,serif" font-size="4.00" fill="White">3_5</text>
# </g>
# <!-- 0_1&#45;&gt;0_2 -->
# <!-- 1_1 -->
# <g id="node22" class="node">
# <title>1_1</title>
# <polygon fill="DimGray" stroke="DimGray" points="142.56,-142.56 72,-142.56 72,-72 142.56,-72 142.56,-142.56"/>
# <text text-ancho

# %% [markdown]
# ------
#
# ## References

# %% [markdown]
# ### Articles
#
# [Wk1] Wikipedia entry, ["Knight's tour"](https://en.wikipedia.org/wiki/Knight%27s_tour).
#
# [Wk2] Wikipedia entry, ["Hamiltonian path problem"](https://en.wikipedia.org/wiki/Hamiltonian_path_problem).

# %% [markdown]
# ### Packages, paclets
#
# [AAp1] Anton Antonvov,
# [Graph Raku package](https://github.com/antononcube/Raku-Graph),
# (2024),
# [GitHub/antononcube](https://github.com/antononcube).
#
# [AAp2] Anton Antonvov,
# [JavaScript::D3 Raku package](https://github.com/antononcube/Raku-JavaScript-D3),
# (2022-2024),
# [GitHub/antononcube](https://github.com/antononcube).

# %% [markdown]
# ### Videos
#
# [AAv1] Anton Antonov,
# [Graph neat examples in Raku (Set 1)](https://youtu.be/5qXgqqRZHow),
# (2024),
# [YouTube/@AAA4prediction](https://www.youtube.com/@AAA4prediction).
#
# [AAv2] Anton Antonov,
# [Graph neat examples in Raku (Set 2)](https://youtu.be/E7qhutQcWCY),
# (2024),
# [YouTube/@AAA4prediction](https://www.youtube.com/@AAA4prediction).
#
# [AAv3] Anton Antonov,
# [Graph neat examples in Raku (Set 3)](),
# (2024),
# [YouTube/@AAA4prediction](https://www.youtube.com/@AAA4prediction).
