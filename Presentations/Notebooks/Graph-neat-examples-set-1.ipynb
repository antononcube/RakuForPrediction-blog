# %% [markdown]
# # Graph neat examples in Raku
#
# ### ***Set 1***
#
# Anton Antonov
# [RakuForPrediction at WordPress](https://rakuforprediction.wordpress.com)
# [RakuForPrediction-book at GitHub](https://github.com/antononcube/RakuForPrediction-book)
# July 2024

# %% [markdown]
# ----
#
# ## Introduction

# %% [markdown]
# **What is a neat example?** : Concise or straightforward code that produces compelling visual or textual outputs.

# %% [markdown]
# **Maybe:** We know *neat* when we see it?

# %% [markdown]
# The neat examples:
#
# - Showcase Raku programming.
# - Use functionalities of different Raku modules.
# - Give interesting perspectives on what is computationally possible.

# %% [markdown]
# Showcased:
# - All computational graph features discussed here are provided by ["Graph"](https://raku.land/zef:antononcube/Graph).
# - Graph plotting -- with `js-d3-graph-plot` -- is provided by ["JavaScript::D3"](https://raku.land/zef:antononcube/JavaScript::D3).
# - ≈ 85,000 English words are provided ["Data::Generators"](https://raku.land/zef:antononcube/Data::Generators).
# - Nearest neighbors computations are provided ["Math::Nearest"](https://raku.land/zef:antononcube/Math::Nearest).
# - The function `dld` is provided by ["Text::Levenshtein::Damerau"](https://raku.land/github:ugexe/Text::Levenshtein::Damerau).
# - Geographical data and `geo-distance` are provided by ["Data::Geographics"](https://raku.land/zef:antononcube/Data::Geographics).
# - The function `cross-tabulate` is provided by ["Data::Reshapers"](https://raku.land/zef:antononcube/Data::Reshapers).

# %% [markdown]
# ------
#
# ## Setup

# %% [markdown]
# Here are loaded the packages used in the rest of notebook:

# %%
use Graph;

use Graph::Circulant;
use Graph::Complete;
use Graph::CompleteKaryTree;
use Graph::Cycle;
use Graph::Grid;
use Graph::Hypercube;
use Graph::KnightTour;
use Graph::Star;
use Graph::Path;
use Graph::Petersen;
use Graph::Wheel;

use Graph::Distribution;
use Graph::Random;

use Data::Reshapers;
use Data::Summarizers;
use Data::Generators;
use Data::TypeSystem;
use Data::Translators;
use Data::Geographics;

use Math::DistanceFunctions;
use Math::Nearest;
use Text::Levenshtein::Damerau;

use Hash::Merge;
use FunctionalParsers;
use FunctionalParsers::EBNF;
use EBNF::Grammar;

use JavaScript::D3;
use WWW::MermaidInk;

# %% [markdown]
# ### JavaScript

# %% [markdown]
# Here we prepare the notebook to visualize with JavaScript:

# %%
#% javascript
require.config({
     paths: {
     d3: 'https://d3js.org/d3.v7.min'
}});

require(['d3'], function(d3) {
     console.log(d3);
});

# %% [markdown]
# Verification:

# %%
#% js
js-d3-list-line-plot(10.rand xx 40, background => 'none', stroke-width => 2)

# %% [markdown]
# Here we set a collection of visualization variables:

# %%
my $title-color = 'Gray'; # 'Ivory';
my $stroke-color = 'SlateGray';
my $tooltip-color = 'LightBlue';
my $tooltip-background-color = 'none';
my $background = '#1F1F1F';
my $color-scheme = 'schemeTableau10';
my $edge-thickness = 3;
my $vertex-size = 6;
my $mmd-theme = q:to/END/;
%%{
  init: {
    'theme': 'forest',
    'themeVariables': {
      'lineColor': 'Ivory'
    }
  }
}%%
END
my %force = collision => {iterations => 0, radius => 10},link => {distance => 180};
my %force2 = charge => {strength => -30, iterations => 4}, collision => {radius => 50, iterations => 4}, link => {distance => 30};

my %opts = :$background, :$title-color, :$edge-thickness, :$vertex-size;
# Out:
# {background => #1F1F1F, edge-thickness => 3, title-color => Gray, vertex-size => 6}

# %% [markdown]
# --------
#
# ## Mod graph

# %% [markdown]
# Make square-&-mod edges and corresponding graph:

# %%
my @redges = (^100).map({ $_.Str => (($_ ** 2) mod 74).Str });
my $gMod = Graph.new(@redges, :directed)
# Out:
# Graph(vertexes => 100, edges => 100, directed => True)

# %% [markdown]
# Plot mod graph:

# %%
#%js
js-d3-graph-plot(
    $gMod.edges(:dataset),
    :$background, :$title-color, 
    edge-thickness => 3, 
    vertex-size => 4,
    vertex-color => 'SlateBlue',
    directed => $gMod.directed,
    title => 'Mod 74 graph', 
    width => 800,
    height => 600, 
    force => {charge => {strength => -100}, y => {strength => 0.12}, link => {minDistance => 4}}
    )

# %% [markdown]
# Plot using [Graphviz](https://graphviz.org) [DOT language](https://graphviz.org/doc/info/lang.html) (with the layout engine ["sfdp"](https://graphviz.org/docs/layouts/)):

# %%
#% html
$gMod.dot(
    :$background, :$title-color, 
    edge-thickness => 3, 
    vertex-size => 4,
    vertex-fill-color => 'SlateBlue',
    directed => $gMod.directed,
    title => 'Mod 74 graph',
    engine => 'sfdp',
    size => 8
):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="473pt"
#  viewBox="0.00 0.00 576.00 473.29" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.650762 0.650762) rotate(0) translate(4 723.29)">
# <polygon fill="#1f1f1f" stroke="none" points="-4,4 -4,-723.29 881.12,-723.29 881.12,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="329.8" cy="-10.8" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="329.8" y="-6.53" font-family="Times,serif" font-size="12.00" fill="White">0</text>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge71" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M339.54,-16.26C348.68,-19.09 358.6,-17.27 358.6,-10.8 358.6,-7.97 356.7,-6.03 353.8,-4.98"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="353.98,-1.47 344.08,-5.23 354.16,-8.47 353.98,-1.47"/>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="228.69" cy="-464.35" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="228.69" y="-460.07" font-family="Times,serif" font-size="12.00" fill="White">1</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge11" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M238.42,-469.8C247.57,-472.63 257.49,-470.81 257.49,-464.35 257.49,-461.52 255.59,-459.58 252.69,-458.53"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="252.87,-455.02 242.96,-458.77 253.05,-462.02 252.87,-455.02"/>
# </g>
# <!-- 10 -->
# <g id="node3" class="node">
# <title>10</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="666.13" cy="-122.96" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="666.13" y="-118.69" font-family="Times,serif" font-size="12.00" fill="White">10</text>
# </g>
# <!-- 26 -->
# <g id="node20" class="node">
# <title>26</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="746.51" cy="-108.74" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="746.51" y="-104.46" font-family="Times,serif" font-size="12.00" fill="White">26</text>
# </g>
# <!-- 10&#45;&gt;26 -->
# <g id="edge95" class="edge">
# <title>10&#45;&gt;26</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M676.79,-125.76C688.73,-125.81 708.42,-122.87 723.83,-119.07"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="724.43,-122.54 733.03,-116.34 722.44,-115.83 724.43,-122.54"/>
# </g>
# <!-- 11 -->
# <g id="node4" class="node">
# <title>11</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="427.85" cy="-647.57" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="427.85" y="-643.29" font-family="Times,serif" font-size="12.00" fill="White">11</text>
# </g>
# <!-- 47 -->
# <g id="node43" class="node">
# <title>47</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="353.89" cy="-603.27" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="353.89" y="-598.99" font-family="Times,serif" font-size="12.00" fill="White">47</text>
# </g>
# <!-- 11&#45;&gt;47 -->
# <g id="edge79" class="edge">
# <title>11&#45;&gt;47</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M418.18,-641.78C407.38,-635.31 389.56,-624.63 375.41,-616.16"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="377.6,-613.39 367.22,-611.26 374,-619.4 377.6,-613.39"/>
# </g>
# <!-- 12 -->
# <g id="node5" class="node">
# <title>12</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="240.76" cy="-257.1" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="240.76" y="-252.83" font-family="Times,serif" font-size="12.00" fill="White">12</text>
# </g>
# <!-- 70 -->
# <g id="node69" class="node">
# <title>70</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="273.56" cy="-199.51" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="273.56" y="-195.23" font-family="Times,serif" font-size="12.00" fill="White">70</text>
# </g>
# <!-- 12&#45;&gt;70 -->
# <g id="edge88" class="edge">
# <title>12&#45;&gt;70</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M246.33,-247.33C250.36,-240.26 255.97,-230.41 261.05,-221.49"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="263.93,-223.5 265.83,-213.08 257.84,-220.04 263.93,-223.5"/>
# </g>
# <!-- 13 -->
# <g id="node6" class="node">
# <title>13</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="669.12" cy="-620.39" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="669.12" y="-616.11" font-family="Times,serif" font-size="12.00" fill="White">13</text>
# </g>
# <!-- 21 -->
# <g id="node15" class="node">
# <title>21</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="629.12" cy="-601.82" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="629.12" y="-597.54" font-family="Times,serif" font-size="12.00" fill="White">21</text>
# </g>
# <!-- 13&#45;&gt;21 -->
# <g id="edge38" class="edge">
# <title>13&#45;&gt;21</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M659.03,-615.7C656.96,-614.74 654.7,-613.69 652.38,-612.62"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="654.01,-609.52 643.47,-608.48 651.07,-615.86 654.01,-609.52"/>
# </g>
# <!-- 14 -->
# <g id="node7" class="node">
# <title>14</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="612.06" cy="-219.61" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="612.06" y="-215.34" font-family="Times,serif" font-size="12.00" fill="White">14</text>
# </g>
# <!-- 48 -->
# <g id="node44" class="node">
# <title>48</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="590.97" cy="-155.12" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="590.97" y="-150.84" font-family="Times,serif" font-size="12.00" fill="White">48</text>
# </g>
# <!-- 14&#45;&gt;48 -->
# <g id="edge98" class="edge">
# <title>14&#45;&gt;48</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M608.57,-208.96C605.93,-200.89 602.2,-189.46 598.85,-179.22"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="602.23,-178.3 595.79,-169.88 595.58,-180.48 602.23,-178.3"/>
# </g>
# <!-- 15 -->
# <g id="node8" class="node">
# <title>15</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="445.8" cy="-514.47" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="445.8" y="-510.2" font-family="Times,serif" font-size="12.00" fill="White">15</text>
# </g>
# <!-- 3 -->
# <g id="node24" class="node">
# <title>3</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="489.82" cy="-512.12" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="489.82" y="-507.85" font-family="Times,serif" font-size="12.00" fill="White">3</text>
# </g>
# <!-- 15&#45;&gt;3 -->
# <g id="edge55" class="edge">
# <title>15&#45;&gt;3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M456.91,-513.88C459.19,-513.76 461.67,-513.62 464.22,-513.49"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="464.23,-516.99 474.03,-512.96 463.86,-510 464.23,-516.99"/>
# </g>
# <!-- 16 -->
# <g id="node9" class="node">
# <title>16</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="345.44" cy="-198.52" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="345.44" y="-194.24" font-family="Times,serif" font-size="12.00" fill="White">16</text>
# </g>
# <!-- 34 -->
# <g id="node29" class="node">
# <title>34</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="381.18" cy="-259.85" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="381.18" y="-255.57" font-family="Times,serif" font-size="12.00" fill="White">34</text>
# </g>
# <!-- 16&#45;&gt;34 -->
# <g id="edge26" class="edge">
# <title>16&#45;&gt;34</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M351.02,-208.1C355.61,-215.98 362.3,-227.45 368.2,-237.59"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="365.17,-239.33 373.23,-246.21 371.22,-235.81 365.17,-239.33"/>
# </g>
# <!-- 17 -->
# <g id="node10" class="node">
# <title>17</t

# %% [markdown]
# Find graphs *weakly* connected components:

# %%
.say for $gMod.weakly-connected-components
# Out:
# [67 57 91 49 81 7 9 71 53 41 35 39 33 25 79 5 69 99 21 13 61 87 95 77 3 89 15 59 83 65 55 93 19 17]
# [56 28 92 18 44 12 30 94 54 20 70 62 32 42 86 16 4 72 76 2 34 58 98 24 50 46 40 52 96 22 90 78]
# [66 64 8 82 26 84 10 48 60 88 14]
# [27 63 47 11 97 23 51 85 45 29]
# [43 73 1 75 31]
# [36 68 6 38 80]
# [0 74]
# [37]

# %% [markdown]
# Plot the components (using `.subgraph`):

# %%
#% js
$gMod.weakly-connected-components.pairs.map({
    js-d3-graph-plot(
        $gMod.subgraph($_.value).edges(:dataset),
        title => ($_.key + 1).Str,
        :$background, :$title-color, :$edge-thickness, vertex-size => 4,
        vertex-color => 'SlateBlue',
        vertex-label-color => 'none',
        force => { charge => {strength => -70}},
    )
}).join("\n")

# %% [markdown]
# Plot with Graphviz DOT only the large enough components:

# %%
#% html
$gMod.weakly-connected-components.grep(*.elems ≥ 10).pairs.map({
    $gMod.subgraph($_.value).dot(
        graph-label => ($_.key + 1).Str,
        :$background, :$title-color, :$edge-thickness, vertex-size => 4,
        vertex-fill-color => 'SlateBlue',
        vertex-label-color => 'none',
        size => 4,
        engine => 'neato'
    ):svg
}).join("\n")
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="264pt" height="288pt"
#  viewBox="0.00 0.00 264.18 288.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.536175 0.536175) rotate(0) translate(4 533.14)">
# <polygon fill="#1f1f1f" stroke="none" points="-4,4 -4,-533.14 488.71,-533.14 488.71,4 -4,4"/>
# <text text-anchor="middle" x="242.35" y="-509.94" font-family="Times,serif" font-size="16.00" fill="White">1</text>
# <!-- 13 -->
# <g id="node1" class="node">
# <title>13</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="108.37" cy="-24.67" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="108.37" y="-20.4" font-family="Times,serif" font-size="12.00" fill="White">13</text>
# </g>
# <!-- 21 -->
# <g id="node5" class="node">
# <title>21</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="119.05" cy="-114.4" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="119.05" y="-110.12" font-family="Times,serif" font-size="12.00" fill="White">21</text>
# </g>
# <!-- 13&#45;&gt;21 -->
# <g id="edge17" class="edge">
# <title>13&#45;&gt;21</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M109.68,-35.67C111.25,-48.86 113.93,-71.37 116.02,-88.95"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="112.53,-89.28 117.19,-98.8 119.48,-88.45 112.53,-89.28"/>
# </g>
# <!-- 15 -->
# <g id="node2" class="node">
# <title>15</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="334.09" cy="-50.03" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="334.09" y="-45.75" font-family="Times,serif" font-size="12.00" fill="White">15</text>
# </g>
# <!-- 3 -->
# <g id="node7" class="node">
# <title>3</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="257.63" cy="-94.1" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="257.63" y="-89.82" font-family="Times,serif" font-size="12.00" fill="White">3</text>
# </g>
# <!-- 15&#45;&gt;3 -->
# <g id="edge33" class="edge">
# <title>15&#45;&gt;3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M324.41,-55.61C313.2,-62.07 294.39,-72.91 279.59,-81.44"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="277.85,-78.4 270.93,-86.43 281.34,-84.47 277.85,-78.4"/>
# </g>
# <!-- 17 -->
# <g id="node3" class="node">
# <title>17</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="15.73" cy="-401.58" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="15.73" y="-397.31" font-family="Times,serif" font-size="12.00" fill="White">17</text>
# </g>
# <!-- 67 -->
# <g id="node20" class="node">
# <title>67</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="93.15" cy="-371.09" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="93.15" y="-366.81" font-family="Times,serif" font-size="12.00" fill="White">67</text>
# </g>
# <!-- 17&#45;&gt;67 -->
# <g id="edge23" class="edge">
# <title>17&#45;&gt;67</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M26.17,-397.47C37.2,-393.13 54.96,-386.13 69.42,-380.44"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="70.63,-383.72 78.65,-376.8 68.06,-377.21 70.63,-383.72"/>
# </g>
# <!-- 19 -->
# <g id="node4" class="node">
# <title>19</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="123.44" cy="-459.76" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="123.44" y="-455.48" font-family="Times,serif" font-size="12.00" fill="White">19</text>
# </g>
# <!-- 65 -->
# <g id="node19" class="node">
# <title>65</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="190.09" cy="-404.65" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="190.09" y="-400.38" font-family="Times,serif" font-size="12.00" fill="White">65</text>
# </g>
# <!-- 19&#45;&gt;65 -->
# <g id="edge4" class="edge">
# <title>19&#45;&gt;65</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M131.88,-452.78C141.54,-444.79 157.69,-431.44 170.53,-420.82"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="172.53,-423.71 178.01,-414.64 168.07,-418.32 172.53,-423.71"/>
# </g>
# <!-- 71 -->
# <g id="node23" class="node">
# <title>71</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="205.39" cy="-161.16" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="205.39" y="-156.88" font-family="Times,serif" font-size="12.00" fill="White">71</text>
# </g>
# <!-- 21&#45;&gt;71 -->
# <g id="edge8" class="edge">
# <title>21&#45;&gt;71</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M128.95,-119.76C142.03,-126.84 165.44,-139.52 182.92,-148.99"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="181.15,-152.01 191.61,-153.69 184.48,-145.85 181.15,-152.01"/>
# </g>
# <!-- 25 -->
# <g id="node6" class="node">
# <title>25</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="377.95" cy="-366.12" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="377.95" y="-361.85" font-family="Times,serif" font-size="12.00" fill="White">25</text>
# </g>
# <!-- 33 -->
# <g id="node8" class="node">
# <title>33</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="294.21" cy="-313.23" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="294.21" y="-308.96" font-family="Times,serif" font-size="12.00" fill="White">33</text>
# </g>
# <!-- 25&#45;&gt;33 -->
# <g id="edge13" class="edge">
# <title>25&#45;&gt;33</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M368.67,-360.26C355.97,-352.24 332.8,-337.6 315.67,-326.78"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="317.7,-323.93 307.38,-321.54 313.96,-329.84 317.7,-323.93"/>
# </g>
# <!-- 9 -->
# <g id="node30" class="node">
# <title>9</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="215.57" cy="-199.99" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="215.57" y="-195.72" font-family="Times,serif" font-size="12.00" fill="White">9</text>
# </g>
# <!-- 3&#45;&gt;9 -->
# <g id="edge5" class="edge">
# <title>3&#45;&gt;9</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M253.6,-104.25C247.05,-120.73 233.94,-153.74 224.96,-176.35"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="221.77,-174.91 221.33,-185.49 228.27,-177.49 221.77,-174.91"/>
# </g>
# <!-- 53 -->
# <g id="node14" class="node">
# <title>53</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="301.86" cy="-220.59" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="301.86" y="-216.31" font-family="Times,serif" font-size="12.00" fill="White">53</text>
# </g>
# <!-- 33&#45;&gt;53 -->
# <g id="edge6" class="edge">
# <title>33&#45;&gt;53</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M295.12,-302.24C296.26,-288.45 298.25,-264.37 299.77,-245.93"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="303.25,-246.35 300.58,-236.09 296.27,-245.77 303.25,-246.35"/>
# </g>
# <!-- 35 -->
# <g id="node9" class="node">
# <title>35</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="444.81" cy="-115.92" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="444.81" y="-111.65" font-family="Times,serif" font-size="12.00" fill="White">35</text>
# </g>
# <!-- 41 -->
# <g id="node11" class="node">
# <title>41</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="389.34" cy="-181.84" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="389.34" y="-177.57" font-family="Times,serif" font-size="12.00" fill="White">41</text>
# </g>
# <!-- 35&#45;&gt;41 -->
# <g id="edge7" class="edge">
# <title>35&#45;&gt;41</title>
# <path fill="none" stroke="SteelBlue" stroke-width="3" d="M437.55,-124.54C429.45,-134.17 416.09,-150.05 405.48,-162.66"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" stroke-width="3" points="403.1,-160.05 399.34,-169.96 408.46,-164.56 403.1,-160.05"/>
# </g>
# <!-- 39 -->
# <g id="node10" class="node">
# <title>39</title>
# <ellipse fill="SlateBlue" stroke="Black" cx="473.91" cy="-183.8" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="473.91" y="-179.53" font-family="Times,serif" font-size="12.00" fill="White">39</text>
# </g>
# <!-- 39&#45;&gt;41 -->

# %% [markdown]
# -----
#
# ## Dictionary graph

# %% [markdown]
# Take all English words from the package ["Data::Generators"](https://raku.land/zef:antononcube/Data::Generators):

# %%
my $ra = Data::Generators::ResourceAccess.instance();
$ra.get-word-data().elems;
# Out:
# 84996

# %% [markdown]
# Those are used by `random-word`:

# %%
random-word(4, type => 'common')
# Out:
# (scabrous degrease prolong heaviness)

# %% [markdown]
# Here is a sample:

# %%
.say for $ra.get-word-data().pick(4)
# Out:
# whatnot => (whatnot True True False 83186)
# basalt => (basalt True True False 7370)
# mispronunciation => (mispronunciation True True False 47754)
# matchweed => (matchweed True False False 45866)

# %% [markdown]
# Find words with the prefix "rac":

# %%
my @words = $ra.get-word-data.keys.grep({ $_.starts-with('rac'):i });
@words.elems
# Out:
# 46

# %% [markdown]
# Compute the corresponding nearest neighbors graph using the two closest neighbors for each word:

# %%
my @nnEdges = nearest-neighbor-graph(@words, 3, distance-function => &dld);
# Out:
# [Rachmaninov => Rachmaninoff Rachmaninov => Racine Rachmaninov => Rachycentron Rachycentridae => Rachycentron Rachycentridae => Rachmaninov Rachycentridae => racketeering racketeering => racketeer racketeering => racking racketeering => racetrack raceme => racemose raceme => race raceme => racer racquet => rachet racquet => racket racquet => raceme racialism => racialist racialism => racial racialism => racially racetrack => raceway racetrack => racecard racetrack => racer racial => racily racial => racing racial => racist Racine => racing Racine => raceme Racine => racial racerunner => raceme racerunner => racquet racerunner => raconteur racking => racing racking => racial racking => Racine Rachycentron => Rachycentridae Rachycentron => Rachmaninov Rachycentron => raccoon raccoon => racoon raccoon => racon raccoon => raceme raconteur => racketeer raconteur => racker raconteur => racon racily => racial racily => racing racily => racist rachitis => rachitic rachitis => rachis rachitis => rachet racemose => raceme racemose => racehorse racemose => racecourse racing => racking racing => racial racing => Racine racoon => raccoon racoon => racon racoon => raceme racist => racism racist => racial racist => racily racy => race racy => rack racy => racily rachischisis => rachitis rachischisis => racialism rachischisis => racialist racketiness => raciness racketiness => racketeer racketiness => racking racially => racial racially => racily racially => racialism raceway => raceme raceway => racial raceway => racily race => racy race => rack race => racer racker => racket racker => racer racker => race rachet => racket rachet => racquet rachet => racist racon => racoon racon => raccoon racon => racing racehorse => racemose racehorse => racecourse racehorse => raceme raceabout => racemose raceabout => racialist raceabout => raceme racecourse => racehorse racecourse => racemose racecourse => racecard Rachmaninoff => Rachmaninov Rachmaninoff => Racine Rachmaninoff => Rachycentron racquetball => racquet ...]

# %% [markdown]
# Make the corresponding directed graph:

# %%
my $gDict = Graph.new(@nnEdges, :directed)
# Out:
# Graph(vertexes => 46, edges => 138, directed => True)

# %% [markdown]
# Plot it:

# %%
#%js
js-d3-graph-plot(
    $gDict.edges(:dataset),
    highlight => <raccoon racoon>,
    :$background, :$title-color, :$edge-thickness, 
    vertex-size => 5,
    vertex-color => 'Blue',
    directed => $gDict.directed,
    title => "«rac» graph", 
    width => 1200,
    height => 650, 
    force => {charge => {strength => -400}, y => {strength => 0.2}, link => {minDistance => 6}}
)

# %% [markdown]
# Plot using Graphviz DOT:

# %%
#%html
$gDict.dot(
    highlight => <raccoon racoon>,
    :$background, :$title-color, :$edge-thickness, 
    vertex-size => 1,
    edge-thickness => 1,
    vertex-fill-color => 'Blue',
    directed => $gDict.directed,
    graph-label => "«rac» graph",
    engine => 'fdp',
    size => 8
):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="533pt" height="576pt"
#  viewBox="0.00 0.00 533.26 576.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.904128 0.904128) rotate(0) translate(4 633.08)">
# <polygon fill="#1f1f1f" stroke="none" points="-4,4 -4,-633.08 585.8,-633.08 585.8,4 -4,4"/>
# <text text-anchor="middle" x="290.9" y="-609.88" font-family="Times,serif" font-size="16.00" fill="White">«rac» graph</text>
# <!-- Rachel -->
# <g id="node1" class="node">
# <title>Rachel</title>
# <ellipse fill="Blue" stroke="Black" cx="349.19" cy="-411.5" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="349.19" y="-407.22" font-family="Times,serif" font-size="12.00" fill="White">Rachel</text>
# </g>
# <!-- Racine -->
# <g id="node6" class="node">
# <title>Racine</title>
# <ellipse fill="Blue" stroke="Black" cx="254.28" cy="-337.32" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="254.28" y="-333.04" font-family="Times,serif" font-size="12.00" fill="White">Racine</text>
# </g>
# <!-- Rachel&#45;&gt;Racine -->
# <g id="edge118" class="edge">
# <title>Rachel&#45;&gt;Racine</title>
# <path fill="none" stroke="SteelBlue" d="M340.43,-404.65C324.89,-392.51 292.23,-366.98 271.88,-351.08"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="274.24,-348.48 264.21,-345.08 269.93,-353.99 274.24,-348.48"/>
# </g>
# <!-- rachet -->
# <g id="node19" class="node">
# <title>rachet</title>
# <ellipse fill="Blue" stroke="Black" cx="383.72" cy="-498.03" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="383.72" y="-493.76" font-family="Times,serif" font-size="12.00" fill="White">rachet</text>
# </g>
# <!-- Rachel&#45;&gt;rachet -->
# <g id="edge100" class="edge">
# <title>Rachel&#45;&gt;rachet</title>
# <path fill="none" stroke="SteelBlue" d="M353.29,-421.76C358.74,-435.42 368.5,-459.89 375.5,-477.43"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="372.11,-478.38 379.06,-486.37 378.61,-475.79 372.11,-478.38"/>
# </g>
# <!-- racial -->
# <g id="node24" class="node">
# <title>racial</title>
# <ellipse fill="Blue" stroke="Black" cx="387.47" cy="-333.05" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="387.47" y="-328.77" font-family="Times,serif" font-size="12.00" fill="White">racial</text>
# </g>
# <!-- Rachel&#45;&gt;racial -->
# <g id="edge73" class="edge">
# <title>Rachel&#45;&gt;racial</title>
# <path fill="none" stroke="SteelBlue" d="M354.04,-401.56C359.93,-389.48 370.02,-368.8 377.58,-353.31"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="380.64,-355.03 381.88,-344.51 374.35,-351.96 380.64,-355.03"/>
# </g>
# <!-- Rachmaninoff -->
# <g id="node2" class="node">
# <title>Rachmaninoff</title>
# <ellipse fill="Blue" stroke="Black" cx="88.72" cy="-363.71" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="88.72" y="-359.43" font-family="Times,serif" font-size="12.00" fill="White">Rachmaninoff</text>
# </g>
# <!-- Rachmaninov -->
# <g id="node3" class="node">
# <title>Rachmaninov</title>
# <ellipse fill="Blue" stroke="Black" cx="84.61" cy="-319.28" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="84.61" y="-315" font-family="Times,serif" font-size="12.00" fill="White">Rachmaninov</text>
# </g>
# <!-- Rachmaninoff&#45;&gt;Rachmaninov -->
# <g id="edge81" class="edge">
# <title>Rachmaninoff&#45;&gt;Rachmaninov</title>
# <path fill="none" stroke="SteelBlue" d="M93.46,-353.77C93.89,-349.51 93.79,-344.37 93.23,-339.38"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="96.75,-339.14 91.46,-329.96 89.87,-340.43 96.75,-339.14"/>
# </g>
# <!-- Rachycentron -->
# <g id="node5" class="node">
# <title>Rachycentron</title>
# <ellipse fill="Blue" stroke="Black" cx="10.88" cy="-306.49" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="10.88" y="-302.21" font-family="Times,serif" font-size="12.00" fill="White">Rachycentron</text>
# </g>
# <!-- Rachmaninoff&#45;&gt;Rachycentron -->
# <g id="edge115" class="edge">
# <title>Rachmaninoff&#45;&gt;Rachycentron</title>
# <path fill="none" stroke="SteelBlue" d="M79.79,-357.14C67.35,-348 44.56,-331.24 28.6,-319.51"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="31.05,-316.97 20.92,-313.87 26.91,-322.61 31.05,-316.97"/>
# </g>
# <!-- Rachmaninoff&#45;&gt;Racine -->
# <g id="edge34" class="edge">
# <title>Rachmaninoff&#45;&gt;Racine</title>
# <path fill="none" stroke="SteelBlue" d="M99.84,-361.93C126.82,-357.63 196.16,-346.58 232.04,-340.86"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="232.39,-344.35 241.71,-339.32 231.28,-337.44 232.39,-344.35"/>
# </g>
# <!-- Rachmaninov&#45;&gt;Rachmaninoff -->
# <g id="edge31" class="edge">
# <title>Rachmaninov&#45;&gt;Rachmaninoff</title>
# <path fill="none" stroke="SteelBlue" d="M79.87,-329.22C79.43,-333.48 79.54,-338.62 80.09,-343.61"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="76.58,-343.85 81.87,-353.03 83.46,-342.55 76.58,-343.85"/>
# </g>
# <!-- Rachmaninov&#45;&gt;Rachycentron -->
# <g id="edge21" class="edge">
# <title>Rachmaninov&#45;&gt;Rachycentron</title>
# <path fill="none" stroke="SteelBlue" d="M75.48,-312.84C64.89,-308.94 47.06,-305.38 32.81,-304.05"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="33.15,-300.56 22.99,-303.57 32.81,-307.55 33.15,-300.56"/>
# </g>
# <!-- Rachmaninov&#45;&gt;Racine -->
# <g id="edge136" class="edge">
# <title>Rachmaninov&#45;&gt;Racine</title>
# <path fill="none" stroke="SteelBlue" d="M95.74,-320.46C123.31,-323.39 195.16,-331.03 231.92,-334.94"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="231.5,-338.42 241.82,-335.99 232.24,-331.46 231.5,-338.42"/>
# </g>
# <!-- Rachycentridae -->
# <g id="node4" class="node">
# <title>Rachycentridae</title>
# <ellipse fill="Blue" stroke="Black" cx="10.07" cy="-273.64" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="10.07" y="-269.37" font-family="Times,serif" font-size="12.00" fill="White">Rachycentridae</text>
# </g>
# <!-- Rachycentridae&#45;&gt;Rachmaninov -->
# <g id="edge65" class="edge">
# <title>Rachycentridae&#45;&gt;Rachmaninov</title>
# <path fill="none" stroke="SteelBlue" d="M19.51,-279.42C30.99,-286.45 50.64,-298.48 65.35,-307.49"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="63.36,-310.38 73.72,-312.61 67.02,-304.41 63.36,-310.38"/>
# </g>
# <!-- Rachycentridae&#45;&gt;Rachycentron -->
# <g id="edge72" class="edge">
# <title>Rachycentridae&#45;&gt;Rachycentron</title>
# <path fill="none" stroke="SteelBlue" d="M4.15,-283.12C4,-284.12 3.88,-285.16 3.81,-286.23"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="0.31,-286.37 4.46,-296.12 7.3,-285.91 0.31,-286.37"/>
# </g>
# <!-- racketeering -->
# <g id="node37" class="node">
# <title>racketeering</title>
# <ellipse fill="Blue" stroke="Black" cx="130.23" cy="-304.01" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="130.23" y="-299.73" font-family="Times,serif" font-size="12.00" fill="White">racketeering</text>
# </g>
# <!-- Rachycentridae&#45;&gt;racketeering -->
# <g id="edge117" class="edge">
# <title>Rachycentridae&#45;&gt;racketeering</title>
# <path fill="none" stroke="SteelBlue" d="M20.74,-276.34C40.37,-281.3 82.6,-291.97 108.5,-298.52"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="107.4,-301.85 117.95,-300.91 109.11,-295.06 107.4,-301.85"/>
# </g>
# <!-- Rachycentron&#45;&gt;Rachmaninov -->
# <g id="edge54" class="edge">
# <title>Rachycentron&#45;&gt;Rachmaninov</title>
# <path fill="none" stroke="SteelBlue" d="M20,-312.93C30.6,-316.83 48.43,-320.38 62.68,-321.72"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="62.34,-325.2 72.5,-322.2 62.68,-318.21 62.34,-325.2"/>
# </g>
# <!-- Rachycentron&#45;&gt;Rachycentridae -->
# <g id="edge46" class="edge">
# <title>Rachycentron&#45;&gt;Rachycentridae</title>
# <path fill="none" stroke="SteelBlue" d="M16.8,-297.01C16.96,-296.01 17.07,-294.97 17.14,-293.9"/>
# <polygon fill="SteelBlue" stroke="SteelBlue" points="20.64,-293.76 16.49,-284.01 13.66,-294.22 20.64,-293.76"/>
# </g>
# <!-- raccoon -->
# <g id="node7" class="node">
# <title>raccoon</title>
# <ellipse fill="DarkOran

# %% [markdown]
# **Remark:** We can derive graph's edges ad hoc, without using `nearest-neighbor-graph`:

# %%
# Construct on nearest finder object over them
my &wn = nearest(@words, distance-function => &dld);

# For each word find the closest two words and make edge rules of the corresponding pairs:
my @redges = @words.map({ $_ <<=><< &wn($_, 3).flat.grep(-> $x { $x ne $_ }) }).flat;
deduce-type(@redges)
# Out:
# Vector(Pair(Atom((Str)), Atom((Str))), 92)

# %% [markdown]
# **Remark:** `nearest` is provided by ["Math::Nearest"](https://raku.land/zef:antononcube/Math::Nearest).

# %% [markdown]
# ------
#
# ## African centers

# %% [markdown]
# Build an interstate highway system joining the geographical centers of all African countries:

# %% [markdown]
# Assign coordinates of the geographical centers and summarize them:

# %%
my %africaCoords = 'Algeria'=>[3.0,28.0],'Libya'=>[17.0,25.0],'Mali'=>[-4.0,17.0],'Mauritania'=>[-12.0,20.0],'Morocco'=>[-5.0,32.0],'Niger'=>[8.0,16.0],'Tunisia'=>[9.0,34.0],'WesternSahara'=>[-13.0,24.5],'Chad'=>[19.0,15.0],'Egypt'=>[30.0,27.0],'Sudan'=>[30.0,13.8],'BurkinaFaso'=>[-2.0,13.0],'Guinea'=>[-10.0,11.0],'IvoryCoast'=>[-5.0,8.0],'Senegal'=>[-14.0,14.0],'Benin'=>[2.25,9.5],'Nigeria'=>[8.0,10.0],'Cameroon'=>[12.0,6.0],'CentralAfricanRepublic'=>[21.0,7.0],'Eritrea'=>[39.0,15.0],'Ethiopia'=>[38.0,8.0],'SouthSudan'=>[30.51,6.7],'Ghana'=>[-2.0,8.0],'Togo'=>[1.1667,8.0],'GuineaBissau'=>[-15.0,12.0],'Liberia'=>[-9.5,6.5],'SierraLeone'=>[-11.5,8.5],'Gambia'=>[-16.5667,13.4667],'EquatorialGuinea'=>[10.0,2.0],'Gabon'=>[11.75,-1.0],'RepublicCongo'=>[15.0,-1.0],'DemocraticRepublicCongo'=>[25.0,0.0],'Djibouti'=>[43.0,11.5],'Kenya'=>[38.0,1.0],'Somalia'=>[49.0,10.0],'Uganda'=>[32.0,1.0],'Angola'=>[18.5,-12.5],'Burundi'=>[30.0,-3.5],'Rwanda'=>[30.0,-2.0],'Tanzania'=>[35.0,-6.0],'Zambia'=>[30.0,-15.0],'Namibia'=>[17.0,-22.0],'Malawi'=>[34.0,-13.5],'Mozambique'=>[35.0,-18.25],'Botswana'=>[24.0,-22.0],'Zimbabwe'=>[30.0,-20.0],'SouthAfrica'=>[24.0,-29.0],'Swaziland'=>[31.5,-26.5],'Lesotho'=>[28.5,-29.5];
sink records-summary(%africaCoords.values)
# Out:
# +---------------------+---------------------+
# | 0                   | 1                   |
# +---------------------+---------------------+
# | Min    => -16.5667  | Min    => -29.5     |
# | 1st-Qu => -2        | 1st-Qu => -2.75     |
# | Mean   => 15.094082 | Mean   => 4.5044224 |
# | Median => 17        | Median => 8         |
# | 3rd-Qu => 30        | 3rd-Qu => 13.9      |
# | Max    => 49        | Max    => 34        |
# +---------------------+---------------------+

# %% [markdown]
# Make a corresponding graph:

# %%
my @africaEdges = %('from'=>'Algeria','to'=>'Libya','weight'=>1),%('from'=>'Algeria','to'=>'Mali','weight'=>1),%('from'=>'Algeria','to'=>'Mauritania','weight'=>1),%('from'=>'Algeria','to'=>'Morocco','weight'=>1),%('from'=>'Algeria','to'=>'Niger','weight'=>1),%('from'=>'Algeria','to'=>'Tunisia','weight'=>1),%('from'=>'Algeria','to'=>'WesternSahara','weight'=>1),%('from'=>'Libya','to'=>'Niger','weight'=>1),%('from'=>'Libya','to'=>'Tunisia','weight'=>1),%('from'=>'Libya','to'=>'Chad','weight'=>1),%('from'=>'Libya','to'=>'Egypt','weight'=>1),%('from'=>'Libya','to'=>'Sudan','weight'=>1),%('from'=>'Mali','to'=>'Mauritania','weight'=>1),%('from'=>'Mali','to'=>'Niger','weight'=>1),%('from'=>'Mali','to'=>'BurkinaFaso','weight'=>1),%('from'=>'Mali','to'=>'Guinea','weight'=>1),%('from'=>'Mali','to'=>'IvoryCoast','weight'=>1),%('from'=>'Mali','to'=>'Senegal','weight'=>1),%('from'=>'Mauritania','to'=>'WesternSahara','weight'=>1),%('from'=>'Mauritania','to'=>'Senegal','weight'=>1),%('from'=>'Morocco','to'=>'WesternSahara','weight'=>1),%('from'=>'Niger','to'=>'Chad','weight'=>1),%('from'=>'Niger','to'=>'BurkinaFaso','weight'=>1),%('from'=>'Niger','to'=>'Benin','weight'=>1),%('from'=>'Niger','to'=>'Nigeria','weight'=>1),%('from'=>'Chad','to'=>'Sudan','weight'=>1),%('from'=>'Chad','to'=>'Nigeria','weight'=>1),%('from'=>'Chad','to'=>'Cameroon','weight'=>1),%('from'=>'Chad','to'=>'CentralAfricanRepublic','weight'=>1),%('from'=>'Egypt','to'=>'Sudan','weight'=>1),%('from'=>'Sudan','to'=>'CentralAfricanRepublic','weight'=>1),%('from'=>'Sudan','to'=>'Eritrea','weight'=>1),%('from'=>'Sudan','to'=>'Ethiopia','weight'=>1),%('from'=>'Sudan','to'=>'SouthSudan','weight'=>1),%('from'=>'BurkinaFaso','to'=>'IvoryCoast','weight'=>1),%('from'=>'BurkinaFaso','to'=>'Benin','weight'=>1),%('from'=>'BurkinaFaso','to'=>'Ghana','weight'=>1),%('from'=>'BurkinaFaso','to'=>'Togo','weight'=>1),%('from'=>'Guinea','to'=>'IvoryCoast','weight'=>1),%('from'=>'Guinea','to'=>'Senegal','weight'=>1),%('from'=>'Guinea','to'=>'GuineaBissau','weight'=>1),%('from'=>'Guinea','to'=>'Liberia','weight'=>1),%('from'=>'Guinea','to'=>'SierraLeone','weight'=>1),%('from'=>'IvoryCoast','to'=>'Ghana','weight'=>1),%('from'=>'IvoryCoast','to'=>'Liberia','weight'=>1),%('from'=>'Senegal','to'=>'GuineaBissau','weight'=>1),%('from'=>'Senegal','to'=>'Gambia','weight'=>1),%('from'=>'Benin','to'=>'Nigeria','weight'=>1),%('from'=>'Benin','to'=>'Togo','weight'=>1),%('from'=>'Nigeria','to'=>'Cameroon','weight'=>1),%('from'=>'Cameroon','to'=>'CentralAfricanRepublic','weight'=>1),%('from'=>'Cameroon','to'=>'EquatorialGuinea','weight'=>1),%('from'=>'Cameroon','to'=>'Gabon','weight'=>1),%('from'=>'Cameroon','to'=>'RepublicCongo','weight'=>1),%('from'=>'CentralAfricanRepublic','to'=>'SouthSudan','weight'=>1),%('from'=>'CentralAfricanRepublic','to'=>'RepublicCongo','weight'=>1),%('from'=>'CentralAfricanRepublic','to'=>'DemocraticRepublicCongo','weight'=>1),%('from'=>'Eritrea','to'=>'Ethiopia','weight'=>1),%('from'=>'Eritrea','to'=>'SouthSudan','weight'=>1),%('from'=>'Eritrea','to'=>'Djibouti','weight'=>1),%('from'=>'Ethiopia','to'=>'SouthSudan','weight'=>1),%('from'=>'Ethiopia','to'=>'Djibouti','weight'=>1),%('from'=>'Ethiopia','to'=>'Kenya','weight'=>1),%('from'=>'Ethiopia','to'=>'Somalia','weight'=>1),%('from'=>'SouthSudan','to'=>'DemocraticRepublicCongo','weight'=>1),%('from'=>'SouthSudan','to'=>'Kenya','weight'=>1),%('from'=>'SouthSudan','to'=>'Uganda','weight'=>1),%('from'=>'Ghana','to'=>'Togo','weight'=>1),%('from'=>'Liberia','to'=>'SierraLeone','weight'=>1),%('from'=>'EquatorialGuinea','to'=>'Gabon','weight'=>1),%('from'=>'Gabon','to'=>'RepublicCongo','weight'=>1),%('from'=>'RepublicCongo','to'=>'DemocraticRepublicCongo','weight'=>1),%('from'=>'RepublicCongo','to'=>'Angola','weight'=>1),%('from'=>'DemocraticRepublicCongo','to'=>'Uganda','weight'=>1),%('from'=>'DemocraticRepublicCongo','to'=>'Angola','weight'=>1),%('from'=>'DemocraticRepublicCongo','to'=>'Burundi','weight'=>1),%('from'=>'DemocraticRepublicCongo','to'=>'Rwanda','weight'=>1),%('from'=>'DemocraticRepublicCongo','to'=>'Tanzania','weight'=>1),%('from'=>'DemocraticRepublicCongo','to'=>'Zambia','weight'=>1),%('from'=>'Djibouti','to'=>'Somalia','weight'=>1),%('from'=>'Kenya','to'=>'Somalia','weight'=>1),%('from'=>'Kenya','to'=>'Uganda','weight'=>1),%('from'=>'Kenya','to'=>'Tanzania','weight'=>1),%('from'=>'Uganda','to'=>'Rwanda','weight'=>1),%('from'=>'Uganda','to'=>'Tanzania','weight'=>1),%('from'=>'Angola','to'=>'Zambia','weight'=>1),%('from'=>'Angola','to'=>'Namibia','weight'=>1),%('from'=>'Burundi','to'=>'Rwanda','weight'=>1),%('from'=>'Burundi','to'=>'Tanzania','weight'=>1),%('from'=>'Rwanda','to'=>'Tanzania','weight'=>1),%('from'=>'Tanzania','to'=>'Zambia','weight'=>1),%('from'=>'Tanzania','to'=>'Malawi','weight'=>1),%('from'=>'Tanzania','to'=>'Mozambique','weight'=>1),%('from'=>'Zambia','to'=>'Namibia','weight'=>1),%('from'=>'Zambia','to'=>'Malawi','weight'=>1),%('from'=>'Zambia','to'=>'Mozambique','weight'=>1),%('from'=>'Zambia','to'=>'Botswana','weight'=>1),%('from'=>'Zambia','to'=>'Zimbabwe','weight'=>1),%('from'=>'Namibia','to'=>'Botswana','weight'=>1),%('from'=>'Namibia','to'=>'SouthAfrica','weight'=>1),%('from'=>'Malawi','to'=>'Mozambique','weight'=>1),%('from'=>'Mozambique','to'=>'Zimbabwe','weight'=>1),%('from'=>'Mozambique','to'=>'SouthAfrica','weight'=>1),%('from'=>'Mozambique','to'=>'Swaziland','weight'=>1),%('from'=>'Botswana','to'=>'Zimbabwe','weight'=>1),%('from'=>'Botswana','to'=>'SouthAfrica','weight'=>1),%('from'=>'Zimbabwe','to'=>'SouthAfrica','weight'=>1),%('from'=>'SouthAfrica','to'=>'Swaziland','weight'=>1),%('from'=>'SouthAfrica','to'=>'Lesotho','weight'=>1);
@africaEdges .= map({ %(from => $_<from>, to => $_<to>, weight => geo-distance(|%africaCoords{$_<from>}, |%africaCoords{$_<to>}, units => 'km' ).round) });

my $gAfrica = Graph.new(@africaEdges, :!directed)
# Out:
# Graph(vertexes => 49, edges => 109, directed => False)

# %% [markdown]
# Find the (minimum) spanning tree:

# %%
my $gAfricaTree = $gAfrica.find-spanning-tree
# Out:
# Graph(vertexes => 49, edges => 48, directed => False)

# %%
#% js
$gAfrica.edges
==> js-d3-graph-plot(
    highlight => [|$gAfricaTree.vertex-list, |$gAfricaTree.edges],
    vertex-coordinates => %africaCoords,
    title => 'Africa geographical centers',
    width => 700,
    height => 700,
    vertex-label-color => 'DimGray',
    margins => {right => 100, top => 80},
    :$background, :$title-color, :$edge-thickness, :$vertex-size,
    )

# %% [markdown]
# Plot using Graphviz DOT:

# %%
#% html
$gAfrica.vertex-coordinates = %africaCoords;
$gAfrica.dot(
    :$background,
    highlight => [|$gAfricaTree.vertex-list, |$gAfricaTree.edges],
    graph-label => 'Africa geographical centers',
    font-size => 120,
    edge-thickness => 20,
    vertex-label-color => 'DimGray',
    vertex-width => 1,
    vertex-font-size => 100,
    size => 7,
    engine => 'neato'
    ):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="504pt" height="503pt"
#  viewBox="0.00 0.00 504.00 503.23" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.104982 0.104982) rotate(0) translate(4 4789.5)">
# <polygon fill="#1f1f1f" stroke="none" points="-4,4 -4,-4789.5 4796.8,-4789.5 4796.8,4 -4,4"/>
# <text text-anchor="middle" x="2396.4" y="-4667.5" font-family="Times,serif" font-size="120.00" fill="White">Africa geographical centers</text>
# <!-- Burundi -->
# <g id="node1" class="node">
# <title>Burundi</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="3388.8" cy="-1908" rx="36" ry="36"/>
# <text text-anchor="middle" x="3388.8" y="-1868.5" font-family="Times,serif" font-size="100.00" fill="White">Burundi</text>
# </g>
# <!-- Tanzania -->
# <g id="node8" class="node">
# <title>Tanzania</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="3748.8" cy="-1728" rx="36" ry="36"/>
# <text text-anchor="middle" x="3748.8" y="-1688.5" font-family="Times,serif" font-size="100.00" fill="White">Tanzania</text>
# </g>
# <!-- Burundi&#45;&#45;Tanzania -->
# <g id="edge72" class="edge">
# <title>Burundi&#45;&#45;Tanzania</title>
# <path fill="none" stroke="SteelBlue" stroke-width="20" d="M3422.88,-1895.5C3492.83,-1864.53 3651.51,-1785.2 3718.3,-1747.8"/>
# <text text-anchor="middle" x="3560.47" y="-1824.85" font-family="Times,serif" font-size="14.00">604</text>
# </g>
# <!-- Burundi&#45;&#45;Tanzania -->
# <g id="edge121" class="edge">
# <title>Burundi&#45;&#45;Tanzania</title>
# <path fill="none" stroke="DarkOrange" stroke-width="20" d="M3419.25,-1888.23C3485.99,-1850.86 3644.67,-1771.52 3714.66,-1740.52"/>
# </g>
# <!-- DemocraticRepublicCongo -->
# <g id="node28" class="node">
# <title>DemocraticRepublicCongo</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="3028.8" cy="-2160" rx="36" ry="36"/>
# <text text-anchor="middle" x="3028.8" y="-2120.5" font-family="Times,serif" font-size="100.00" fill="White">DemocraticRepublicCongo</text>
# </g>
# <!-- Burundi&#45;&#45;DemocraticRepublicCongo -->
# <g id="edge10" class="edge">
# <title>Burundi&#45;&#45;DemocraticRepublicCongo</title>
# <path fill="none" stroke="SteelBlue" stroke-width="20" d="M3359.04,-1928.84C3291.31,-1976.24 3126.36,-2091.71 3058.6,-2139.14"/>
# <text text-anchor="middle" x="3198.69" y="-2037.19" font-family="Times,serif" font-size="14.00">655</text>
# </g>
# <!-- Rwanda -->
# <g id="node47" class="node">
# <title>Rwanda</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="3388.8" cy="-2016" rx="36" ry="36"/>
# <text text-anchor="middle" x="3388.8" y="-1976.5" font-family="Times,serif" font-size="100.00" fill="White">Rwanda</text>
# </g>
# <!-- Burundi&#45;&#45;Rwanda -->
# <g id="edge90" class="edge">
# <title>Burundi&#45;&#45;Rwanda</title>
# <path fill="none" stroke="SteelBlue" stroke-width="20" d="M3382.41,-1943.66C3381.93,-1955.46 3381.93,-1968.58 3382.41,-1980.37"/>
# <text text-anchor="middle" x="3372.29" y="-1965.22" font-family="Times,serif" font-size="14.00">145</text>
# </g>
# <!-- Burundi&#45;&#45;Rwanda -->
# <g id="edge120" class="edge">
# <title>Burundi&#45;&#45;Rwanda</title>
# <path fill="none" stroke="DarkOrange" stroke-width="20" d="M3395.19,-1943.66C3395.67,-1955.46 3395.67,-1968.58 3395.19,-1980.37"/>
# </g>
# <!-- RepublicCongo -->
# <g id="node2" class="node">
# <title>RepublicCongo</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="2308.8" cy="-2088" rx="36" ry="36"/>
# <text text-anchor="middle" x="2308.8" y="-2048.5" font-family="Times,serif" font-size="100.00" fill="White">RepublicCongo</text>
# </g>
# <!-- Guinea -->
# <g id="node3" class="node">
# <title>Guinea</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="508.8" cy="-2952" rx="36" ry="36"/>
# <text text-anchor="middle" x="508.8" y="-2912.5" font-family="Times,serif" font-size="100.00" fill="White">Guinea</text>
# </g>
# <!-- IvoryCoast -->
# <g id="node14" class="node">
# <title>IvoryCoast</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="868.8" cy="-2736" rx="36" ry="36"/>
# <text text-anchor="middle" x="868.8" y="-2696.5" font-family="Times,serif" font-size="100.00" fill="White">IvoryCoast</text>
# </g>
# <!-- Guinea&#45;&#45;IvoryCoast -->
# <g id="edge70" class="edge">
# <title>Guinea&#45;&#45;IvoryCoast</title>
# <path fill="none" stroke="SteelBlue" stroke-width="20" d="M539.81,-2933.4C607.86,-2892.57 769.65,-2795.49 837.74,-2754.63"/>
# <text text-anchor="middle" x="678.65" y="-2847.22" font-family="Times,serif" font-size="14.00">648</text>
# </g>
# <!-- Senegal -->
# <g id="node17" class="node">
# <title>Senegal</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="220.8" cy="-3168" rx="36" ry="36"/>
# <text text-anchor="middle" x="220.8" y="-3128.5" font-family="Times,serif" font-size="100.00" fill="White">Senegal</text>
# </g>
# <!-- Guinea&#45;&#45;Senegal -->
# <g id="edge84" class="edge">
# <title>Guinea&#45;&#45;Senegal</title>
# <path fill="none" stroke="SteelBlue" stroke-width="20" d="M477.31,-2970.29C420.12,-3009.04 300.36,-3098.86 247.16,-3142.91"/>
# <text text-anchor="middle" x="352.11" y="-3059.8" font-family="Times,serif" font-size="14.00">552</text>
# </g>
# <!-- Guinea&#45;&#45;Senegal -->
# <g id="edge139" class="edge">
# <title>Guinea&#45;&#45;Senegal</title>
# <path fill="none" stroke="DarkOrange" stroke-width="20" d="M482.42,-2977.11C429.21,-3021.17 309.45,-3110.99 252.27,-3149.72"/>
# </g>
# <!-- Liberia -->
# <g id="node32" class="node">
# <title>Liberia</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="544.8" cy="-2628" rx="36" ry="36"/>
# <text text-anchor="middle" x="544.8" y="-2588.5" font-family="Times,serif" font-size="100.00" fill="White">Liberia</text>
# </g>
# <!-- Guinea&#45;&#45;Liberia -->
# <g id="edge55" class="edge">
# <title>Guinea&#45;&#45;Liberia</title>
# <path fill="none" stroke="SteelBlue" stroke-width="20" d="M512.83,-2915.78C519.76,-2853.36 533.89,-2726.25 540.8,-2663.99"/>
# <text text-anchor="middle" x="516.69" y="-2793.08" font-family="Times,serif" font-size="14.00">497</text>
# </g>
# <!-- SierraLeone -->
# <g id="node40" class="node">
# <title>SierraLeone</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="400.8" cy="-2772" rx="36" ry="36"/>
# <text text-anchor="middle" x="400.8" y="-2732.5" font-family="Times,serif" font-size="100.00" fill="White">SierraLeone</text>
# </g>
# <!-- Guinea&#45;&#45;SierraLeone -->
# <g id="edge50" class="edge">
# <title>Guinea&#45;&#45;SierraLeone</title>
# <path fill="none" stroke="SteelBlue" stroke-width="20" d="M494.73,-2918.36C476.62,-2884.25 445.34,-2832.14 423.8,-2800.15"/>
# <text text-anchor="middle" x="449.14" y="-2845.95" font-family="Times,serif" font-size="14.00">320</text>
# </g>
# <!-- Guinea&#45;&#45;SierraLeone -->
# <g id="edge140" class="edge">
# <title>Guinea&#45;&#45;SierraLeone</title>
# <path fill="none" stroke="DarkOrange" stroke-width="20" d="M485.74,-2923.75C464.17,-2891.72 432.91,-2839.6 414.82,-2805.53"/>
# </g>
# <!-- GuineaBissau -->
# <g id="node45" class="node">
# <title>GuineaBissau</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="148.8" cy="-3024" rx="36" ry="36"/>
# <text text-anchor="middle" x="148.8" y="-2984.5" font-family="Times,serif" font-size="100.00" fill="White">GuineaBissau</text>
# </g>
# <!-- Guinea&#45;&#45;GuineaBissau -->
# <g id="edge42" class="edge">
# <title>Guinea&#45;&#45;GuineaBissau</title>
# <path fill="none" stroke="SteelBlue" stroke-width="20" d="M473.3,-2959.1C404.47,-2972.87 253.61,-3003.04 184.57,-3016.85"/>
# <text text-anchor="middle" x="318.81" y="-2991.17" font-family="Times,serif" font-size="14.00">567</text>
# </g>
# <!-- Mali -->
# <g id="node49" class="node">
# <title>Mali</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="940.8" cy="-3384" rx="36" ry="36"/>
# <text text-anchor="middle" x="940.8" y="-3344.5" font-family="Times,serif" font-size="100.00" fill="White">Mali</text>
# </g>
# <!-- Guinea&#45;&#45;Mali -->
# <g id="edge30" class="edge">
# <title

# %% [markdown]
# ### Distances

# %% [markdown]
# Cross-tabulate countries and distances:

# %%
my @tbl = (%africaCoords X %africaCoords).map({ %( from => $_.head.key, to => $_.tail.key, weight => &geo-distance($_.head.value, $_.tail.value, units => 'miles').round(0.1) ) });
my @ct = cross-tabulate(@tbl, 'from', 'to', 'weight').sort(*.key);

deduce-type(@ct)
# Out:
# Vector(Pair(Atom((Str)), Assoc(Atom((Str)), Atom((Rat)), 49)), 49)

# %% [markdown]
# **Remark:** `cross-tabulate` is provided by ["Data::Reshapers"](https://raku.land/zef:antononcube/Data::Reshapers).

# %% [markdown]
# Show table:

# %%
#% html
@ct.map({ ['from' => $_.key , |$_.value].Hash }) ==> to-html(field-names => ['from', |@ct>>.key])
# Out:
# <table border="1"><thead><tr><th>from</th><th>Algeria</th><th>Angola</th><th>Benin</th><th>Botswana</th><th>BurkinaFaso</th><th>Burundi</th><th>Cameroon</th><th>CentralAfricanRepublic</th><th>Chad</th><th>DemocraticRepublicCongo</th><th>Djibouti</th><th>Egypt</th><th>EquatorialGuinea</th><th>Eritrea</th><th>Ethiopia</th><th>Gabon</th><th>Gambia</th><th>Ghana</th><th>Guinea</th><th>GuineaBissau</th><th>IvoryCoast</th><th>Kenya</th><th>Lesotho</th><th>Liberia</th><th>Libya</th><th>Malawi</th><th>Mali</th><th>Mauritania</th><th>Morocco</th><th>Mozambique</th><th>Namibia</th><th>Niger</th><th>Nigeria</th><th>RepublicCongo</th><th>Rwanda</th><th>Senegal</th><th>SierraLeone</th><th>Somalia</th><th>SouthAfrica</th><th>SouthSudan</th><th>Sudan</th><th>Swaziland</th><th>Tanzania</th><th>Togo</th><th>Tunisia</th><th>Uganda</th><th>WesternSahara</th><th>Zambia</th><th>Zimbabwe</th></tr></thead><tbody><tr><td>Algeria</td><td>0</td><td>2943</td><td>1279.3</td><td>3636.8</td><td>1093.3</td><td>2782.1</td><td>1630.5</td><td>1883.9</td><td>1413.6</td><td>2406.5</td><td>2947.4</td><td>1868.8</td><td>1850</td><td>2621.3</td><td>2731.8</td><td>2077.1</td><td>1678.7</td><td>1425.5</td><td>1476.5</td><td>1658.7</td><td>1488.7</td><td>2962.5</td><td>4166.2</td><td>1715.6</td><td>989.6</td><td>3424.6</td><td>901.5</td><td>1174.3</td><td>618.6</td><td>3696.3</td><td>3528.5</td><td>895.4</td><td>1286.3</td><td>2144</td><td>2710.3</td><td>1518.2</td><td>1674.9</td><td>3354.9</td><td>4066.6</td><td>2358</td><td>2086.5</td><td>4049.7</td><td>3106.6</td><td>1388.2</td><td>585.2</td><td>2664.9</td><td>1132.5</td><td>3375.6</td><td>3650.9</td></tr><tr><td>Angola</td><td>2943</td><td>0</td><td>1867.2</td><td>720.6</td><td>2241</td><td>976.3</td><td>1312.8</td><td>1280.4</td><td>1799.7</td><td>919.6</td><td>2198.8</td><td>2600.3</td><td>1135</td><td>2173.1</td><td>1829.6</td><td>898.2</td><td>3001.2</td><td>1989.3</td><td>2541.3</td><td>2855.9</td><td>2143.8</td><td>1575.8</td><td>1278.8</td><td>2330.8</td><td>2468.2</td><td>1073.9</td><td>2542.2</td><td>3060.5</td><td>3441</td><td>1194.6</td><td>634.3</td><td>2047.8</td><td>1677.3</td><td>799</td><td>1033.8</td><td>2884</td><td>2521.8</td><td>2454.5</td><td>1128.7</td><td>1462.7</td><td>1833.2</td><td>1254.1</td><td>1209</td><td>1836.5</td><td>3183.4</td><td>1256.7</td><td>3333.8</td><td>810.9</td><td>924.8</td></tr><tr><td>Benin</td><td>1279.3</td><td>1867.2</td><td>0</td><td>2587.8</td><td>380.8</td><td>2100.5</td><td>715.8</td><td>1307.9</td><td>1217</td><td>1696.4</td><td>2821.4</td><td>2236.6</td><td>743.7</td><td>2565.6</td><td>2474.7</td><td>974.8</td><td>1329.5</td><td>311.7</td><td>853.6</td><td>1205.4</td><td>512.1</td><td>2530.9</td><td>3145.8</td><td>838.6</td><td>1466.8</td><td>2651</td><td>675.1</td><td>1221.7</td><td>1633.7</td><td>2882.9</td><td>2371.6</td><td>598.8</td><td>399.2</td><td>1136.3</td><td>2062.5</td><td>1165.6</td><td>953.6</td><td>3233.9</td><td>2980.1</td><td>1963.4</td><td>1940.1</td><td>3097.7</td><td>2474.9</td><td>127.9</td><td>1748.9</td><td>2131</td><td>1474.2</td><td>2503.2</td><td>2724.9</td></tr><tr><td>Botswana</td><td>3636.8</td><td>720.6</td><td>2587.8</td><td>0</td><td>2960.8</td><td>1211.5</td><td>2014.7</td><td>1861.6</td><td>2399.4</td><td>1385</td><td>2312.6</td><td>3025.9</td><td>1854.4</td><td>2394.5</td><td>2012.2</td><td>1617.9</td><td>3689</td><td>2701.9</td><td>3240.7</td><td>3543.2</td><td>2848.2</td><td>1664.7</td><td>559.6</td><td>3012.8</td><td>3069.7</td><td>861.1</td><td>3262.6</td><td>3775.7</td><td>4152.6</td><td>793.5</td><td>484.2</td><td>2745.6</td><td>2388.7</td><td>1501.6</td><td>1298.4</td><td>3581.5</td><td>3206.1</td><td>2447.9</td><td>442.3</td><td>1815.9</td><td>2235.8</td><td>587.2</td><td>1224.6</td><td>2555.1</td><td>3830.4</td><td>1505.8</td><td>4052.4</td><td>598.3</td><td>432.9</td></tr><tr><td>BurkinaFaso</td><td>1093.3</td><td>2241</td><td>380.8</td><td>2960.8</td><td>0</td><td>2467.2</td><td>1081.3</td><td>1642</td><td>1458.9</ ...

# %% [markdown]
# Graph based on the distance table:

# %%
my $gAfricaComplete = Graph.new(@tbl)
# Out:
# Graph(vertexes => 49, edges => 1225, directed => False)

# %% [markdown]
# Edge count verification:

# %%
$gAfricaComplete.vertex-list.combinations(2).elems + $gAfricaComplete.vertex-count
# Out:
# 1225

# %% [markdown]
# Spanning tree:

# %%
my $gAfricaTree2 = $gAfricaComplete.find-spanning-tree
# Out:
# Graph(vertexes => 49, edges => 48, directed => False)

# %% [markdown]
# Plot graph:

# %%
#% js
js-d3-graph-plot(
    $gAfricaTree2.edges,
    highlight => [|$gAfricaTree2.vertex-list, |$gAfricaTree2.edges],
    vertex-coordinates => %africaCoords,
    title => 'Africa geographical centers',
    width => 700,
    height => 700,
    vertex-label-color => 'Silver',
    margins => {right => 100, top => 80},
    :$background, :$title-color, :$edge-thickness, :$vertex-size,
    )

# %% [markdown]
# Plot with Graphviz DOT:

# %%
#% html
$gAfricaTree2.vertex-coordinates = %africaCoords;
$gAfricaTree2.dot(
    :$background,
    graph-label => 'Africa geographical centers',
    font-size => 120,
    edge-thickness => 20,
    edge-color => 'Orange',
    vertex-fill-color => 'Orange',
    vertex-label-color => 'DimGray',
    vertex-width => 1,
    vertex-font-size => 100,
    size => 7,
    engine => 'neato'
    ):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="504pt" height="503pt"
#  viewBox="0.00 0.00 504.00 503.23" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.104982 0.104982) rotate(0) translate(4 4789.5)">
# <polygon fill="#1f1f1f" stroke="none" points="-4,4 -4,-4789.5 4796.8,-4789.5 4796.8,4 -4,4"/>
# <text text-anchor="middle" x="2396.4" y="-4667.5" font-family="Times,serif" font-size="120.00" fill="White">Africa geographical centers</text>
# <!-- Burundi -->
# <g id="node1" class="node">
# <title>Burundi</title>
# <ellipse fill="Orange" stroke="Black" cx="3388.8" cy="-1908" rx="36" ry="36"/>
# <text text-anchor="middle" x="3388.8" y="-1868.5" font-family="Times,serif" font-size="100.00" fill="White">Burundi</text>
# </g>
# <!-- Tanzania -->
# <g id="node8" class="node">
# <title>Tanzania</title>
# <ellipse fill="Orange" stroke="Black" cx="3748.8" cy="-1728" rx="36" ry="36"/>
# <text text-anchor="middle" x="3748.8" y="-1688.5" font-family="Times,serif" font-size="100.00" fill="White">Tanzania</text>
# </g>
# <!-- Burundi&#45;&#45;Tanzania -->
# <g id="edge25" class="edge">
# <title>Burundi&#45;&#45;Tanzania</title>
# <path fill="none" stroke="Orange" stroke-width="20" d="M3421.38,-1891.71C3489.84,-1857.48 3647.91,-1778.45 3716.29,-1744.25"/>
# <text text-anchor="middle" x="3553.46" y="-1821.18" font-family="Times,serif" font-size="14.00">375.3</text>
# </g>
# <!-- Rwanda -->
# <g id="node47" class="node">
# <title>Rwanda</title>
# <ellipse fill="Orange" stroke="Black" cx="3388.8" cy="-2016" rx="36" ry="36"/>
# <text text-anchor="middle" x="3388.8" y="-1976.5" font-family="Times,serif" font-size="100.00" fill="White">Rwanda</text>
# </g>
# <!-- Burundi&#45;&#45;Rwanda -->
# <g id="edge26" class="edge">
# <title>Burundi&#45;&#45;Rwanda</title>
# <path fill="none" stroke="Orange" stroke-width="20" d="M3388.8,-1944.26C3388.8,-1955.66 3388.8,-1968.24 3388.8,-1979.65"/>
# <text text-anchor="middle" x="3376.8" y="-1965.16" font-family="Times,serif" font-size="14.00">89.9</text>
# </g>
# <!-- RepublicCongo -->
# <g id="node2" class="node">
# <title>RepublicCongo</title>
# <ellipse fill="Orange" stroke="Black" cx="2308.8" cy="-2088" rx="36" ry="36"/>
# <text text-anchor="middle" x="2308.8" y="-2048.5" font-family="Times,serif" font-size="100.00" fill="White">RepublicCongo</text>
# </g>
# <!-- Guinea -->
# <g id="node3" class="node">
# <title>Guinea</title>
# <ellipse fill="Orange" stroke="Black" cx="508.8" cy="-2952" rx="36" ry="36"/>
# <text text-anchor="middle" x="508.8" y="-2912.5" font-family="Times,serif" font-size="100.00" fill="White">Guinea</text>
# </g>
# <!-- SierraLeone -->
# <g id="node40" class="node">
# <title>SierraLeone</title>
# <ellipse fill="Orange" stroke="Black" cx="400.8" cy="-2772" rx="36" ry="36"/>
# <text text-anchor="middle" x="400.8" y="-2732.5" font-family="Times,serif" font-size="100.00" fill="White">SierraLeone</text>
# </g>
# <!-- Guinea&#45;&#45;SierraLeone -->
# <g id="edge23" class="edge">
# <title>Guinea&#45;&#45;SierraLeone</title>
# <path fill="none" stroke="Orange" stroke-width="20" d="M490.24,-2921.06C470.45,-2888.09 439.31,-2836.19 419.49,-2803.14"/>
# <text text-anchor="middle" x="439.49" y="-2865.3" font-family="Times,serif" font-size="14.00">199.1</text>
# </g>
# <!-- Zimbabwe -->
# <g id="node4" class="node">
# <title>Zimbabwe</title>
# <ellipse fill="Orange" stroke="Black" cx="3388.8" cy="-720" rx="36" ry="36"/>
# <text text-anchor="middle" x="3388.8" y="-680.5" font-family="Times,serif" font-size="100.00" fill="White">Zimbabwe</text>
# </g>
# <!-- Niger -->
# <g id="node5" class="node">
# <title>Niger</title>
# <ellipse fill="Orange" stroke="Black" cx="1804.8" cy="-3312" rx="36" ry="36"/>
# <text text-anchor="middle" x="1804.8" y="-3272.5" font-family="Times,serif" font-size="100.00" fill="White">Niger</text>
# </g>
# <!-- Nigeria -->
# <g id="node25" class="node">
# <title>Nigeria</title>
# <ellipse fill="Orange" stroke="Black" cx="1804.8" cy="-2880" rx="36" ry="36"/>
# <text text-anchor="middle" x="1804.8" y="-2840.5" font-family="Times,serif" font-size="100.00" fill="White">Nigeria</text>
# </g>
# <!-- Niger&#45;&#45;Nigeria -->
# <g id="edge29" class="edge">
# <title>Niger&#45;&#45;Nigeria</title>
# <path fill="none" stroke="Orange" stroke-width="20" d="M1804.8,-3275.54C1804.8,-3193.97 1804.8,-2997.54 1804.8,-2916.21"/>
# <text text-anchor="middle" x="1794.68" y="-3099.07" font-family="Times,serif" font-size="14.00">411</text>
# </g>
# <!-- Cameroon -->
# <g id="node6" class="node">
# <title>Cameroon</title>
# <ellipse fill="Orange" stroke="Black" cx="2092.8" cy="-2592" rx="36" ry="36"/>
# <text text-anchor="middle" x="2092.8" y="-2552.5" font-family="Times,serif" font-size="100.00" fill="White">Cameroon</text>
# </g>
# <!-- EquatorialGuinea -->
# <g id="node22" class="node">
# <title>EquatorialGuinea</title>
# <ellipse fill="Orange" stroke="Black" cx="1948.8" cy="-2304" rx="36" ry="36"/>
# <text text-anchor="middle" x="1948.8" y="-2264.5" font-family="Times,serif" font-size="100.00" fill="White">EquatorialGuinea</text>
# </g>
# <!-- Cameroon&#45;&#45;EquatorialGuinea -->
# <g id="edge3" class="edge">
# <title>Cameroon&#45;&#45;EquatorialGuinea</title>
# <path fill="none" stroke="Orange" stroke-width="20" d="M2076.56,-2559.52C2048.83,-2504.06 1992.67,-2391.74 1964.98,-2336.36"/>
# <text text-anchor="middle" x="2005.4" y="-2451.14" font-family="Times,serif" font-size="14.00">304.8</text>
# </g>
# <!-- Cameroon&#45;&#45;Nigeria -->
# <g id="edge1" class="edge">
# <title>Cameroon&#45;&#45;Nigeria</title>
# <path fill="none" stroke="Orange" stroke-width="20" d="M2067.24,-2617.56C2012.59,-2672.21 1884.91,-2799.9 1830.3,-2854.5"/>
# <text text-anchor="middle" x="1933.4" y="-2739.23" font-family="Times,serif" font-size="14.00">388.3</text>
# </g>
# <!-- CentralAfricanRepublic -->
# <g id="node26" class="node">
# <title>CentralAfricanRepublic</title>
# <ellipse fill="Orange" stroke="Black" cx="2740.8" cy="-2664" rx="36" ry="36"/>
# <text text-anchor="middle" x="2740.8" y="-2624.5" font-family="Times,serif" font-size="100.00" fill="White">CentralAfricanRepublic</text>
# </g>
# <!-- Cameroon&#45;&#45;CentralAfricanRepublic -->
# <g id="edge2" class="edge">
# <title>Cameroon&#45;&#45;CentralAfricanRepublic</title>
# <path fill="none" stroke="Orange" stroke-width="20" d="M2129.03,-2596.03C2242.71,-2608.66 2591.51,-2647.41 2704.83,-2660"/>
# <text text-anchor="middle" x="2401.56" y="-2631.21" font-family="Times,serif" font-size="14.00">626.1</text>
# </g>
# <!-- Ghana -->
# <g id="node7" class="node">
# <title>Ghana</title>
# <ellipse fill="Orange" stroke="Black" cx="1084.8" cy="-2736" rx="36" ry="36"/>
# <text text-anchor="middle" x="1084.8" y="-2696.5" font-family="Times,serif" font-size="100.00" fill="White">Ghana</text>
# </g>
# <!-- IvoryCoast -->
# <g id="node14" class="node">
# <title>IvoryCoast</title>
# <ellipse fill="Orange" stroke="Black" cx="868.8" cy="-2736" rx="36" ry="36"/>
# <text text-anchor="middle" x="868.8" y="-2696.5" font-family="Times,serif" font-size="100.00" fill="White">IvoryCoast</text>
# </g>
# <!-- Ghana&#45;&#45;IvoryCoast -->
# <g id="edge13" class="edge">
# <title>Ghana&#45;&#45;IvoryCoast</title>
# <path fill="none" stroke="Orange" stroke-width="20" d="M1048.65,-2736C1008.78,-2736 944.99,-2736 905.07,-2736"/>
# <text text-anchor="middle" x="961.49" y="-2739.2" font-family="Times,serif" font-size="14.00">207.5</text>
# </g>
# <!-- Togo -->
# <g id="node44" class="node">
# <title>Togo</title>
# <ellipse fill="Orange" stroke="Black" cx="1312.8" cy="-2736" rx="36" ry="36"/>
# <text text-anchor="middle" x="1312.8" y="-2696.5" font-family="Times,serif" font-size="100.00" fill="White">Togo</text>
# </g>
# <!-- Ghana&#45;&#45;Togo -->
# <g id="edge11" class="edge">
# <title>Ghana&#45;&#45;Togo</title>
# <path fill="none" stroke="Orange" stroke-width="20" d="M1121.18,-2736C1163.8,-2736 1233.99,-2736 1276.55,-2736"/>
# <text text-anchor="middle" x="1188.74" y="-2739.2" font-family="Times,serif" font-size="14.00

# %% [markdown]
# -----
#
# ## Bulgarian cities

# %% [markdown]
# Build an interstate highway system joining the cities of Bulgaria.

# %%
city-data().map(*<Country>).unique.sort
# Out:
# (Botswana Bulgaria Canada Germany Hungary Russia Spain Ukraine United States)

# %% [markdown]
# Here is a dataset of large enough cities:

# %%
my $maxPop = 10_000;
my @cities = city-data().grep({ $_<Country> eq 'Bulgaria' && $_<Population> ≥ $maxPop });
@cities.elems
# Out:
# 84

# %% [markdown]
# **Remark:** Geographical data and geo-distance computation is provided by ["Data::Geographics"](https://raku.land/zef:antononcube/Data::Geographics).

# %%
#% html
@cities.head(4) 
==> to-html(field-names => <ID Country State City Latitude Longitude Elevation LocationLink>)
# Out:
# <table border="1"><thead><tr><th>ID</th><th>Country</th><th>State</th><th>City</th><th>Latitude</th><th>Longitude</th><th>Elevation</th><th>LocationLink</th></tr></thead><tbody><tr><td>Bulgaria.Sofia_grad.Sofia</td><td>Bulgaria</td><td>Sofia grad</td><td>Sofia</td><td>42.69</td><td>23.31</td><td>570</td><td>http://maps.google.com/maps?q=42.69,23.31&amp;z=12&amp;t=h</td></tr><tr><td>Bulgaria.Plovdiv.Plovdiv</td><td>Bulgaria</td><td>Plovdiv</td><td>Plovdiv</td><td>42.15</td><td>24.75</td><td>170</td><td>http://maps.google.com/maps?q=42.15,24.75&amp;z=12&amp;t=h</td></tr><tr><td>Bulgaria.Varna.Varna</td><td>Bulgaria</td><td>Varna</td><td>Varna</td><td>43.21</td><td>27.900000000000002</td><td>16</td><td>http://maps.google.com/maps?q=43.21,27.900000000000002&amp;z=12&amp;t=h</td></tr><tr><td>Bulgaria.Burgas.Burgas</td><td>Bulgaria</td><td>Burgas</td><td>Burgas</td><td>42.51</td><td>27.47</td><td>30</td><td>http://maps.google.com/maps?q=42.51,27.47&amp;z=12&amp;t=h</td></tr></tbody></table>

# %% [markdown]
# Here is the corresponding weighted **complete** graph:

# %%
my %coords = @cities.map({ $_<City> => ($_<Latitude>, $_<Longitude>) });
my @dsEdges = (%coords.keys X %coords.keys ).map({ %(from => $_.head, to => $_.tail, weight => geo-distance(|%coords{$_.head}, |%coords{$_.tail} )) });
my $gGeo = Graph.new(@dsEdges, :!directed)
# Out:
# Graph(vertexes => 84, edges => 3570, directed => False)

# %% [markdown]
# Here is the corresponding spanning tree:

# %%
my $stree = $gGeo.find-spanning-tree(method => 'kruskal')
# Out:
# Graph(vertexes => 84, edges => 83, directed => False)

# %%
#% js
$stree.edges
==> js-d3-graph-plot(
    vertex-coordinates => %coords.nodemap(*.reverse)».List.Hash,
    title => "Bulgaria, cities with population ≥ $maxPop",
    width => 1400,
    height => 700,
    :$background, :$title-color, :$edge-thickness, 
    vertex-size => 4,
    vertex-label-font-size => 8,
    vertex-label-font-family => Whatever,
    margins => {right => 200}
    )

# %% [markdown]
# Gravphviz DOT plot:

# %%
#% html
# In order to remove the edge weights we just copy the "simple" edges.
my $stree2 = Graph.new($stree.edges);
$stree2.vertex-coordinates = %coords.nodemap(*.reverse)».List.Hash;
$stree2.dot(
    :$background, 
    graph-label => "Bulgaria, cities with population ≥ $maxPop",
    font-size => 12,
    edge-thickness => 1,
    vertex-width => 0.4,
    vertex-height => 0.07,
    vertex-shape => 'rectangle',
    vertex-color => 'none',
    vertex-fill-color => $background,
    vertex-font-size => 6,
    size => 12,
    engine => 'neato'
    ):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="864pt" height="449pt"
#  viewBox="0.00 0.00 864.00 448.77" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.9477 1.9477) rotate(0) translate(4 226.41)">
# <polygon fill="#1f1f1f" stroke="none" points="-4,4 -4,-226.41 439.6,-226.41 439.6,4 -4,4"/>
# <text text-anchor="middle" x="217.8" y="-207.01" font-family="Times,serif" font-size="12.00" fill="White">Bulgaria, cities with population ≥ 10000</text>
# <!-- Lom -->
# <g id="node1" class="node">
# <title>Lom</title>
# <polygon fill="#1f1f1f" stroke="none" points="69.12,-180 40.32,-180 40.32,-174.96 69.12,-174.96 69.12,-180"/>
# <text text-anchor="middle" x="54.72" y="-175.53" font-family="Times,serif" font-size="6.00" fill="White">Lom</text>
# </g>
# <!-- Vidin -->
# <g id="node32" class="node">
# <title>Vidin</title>
# <polygon fill="#1f1f1f" stroke="none" points="41.76,-192.96 12.96,-192.96 12.96,-187.92 41.76,-187.92 41.76,-192.96"/>
# <text text-anchor="middle" x="27.36" y="-188.49" font-family="Times,serif" font-size="6.00" fill="White">Vidin</text>
# </g>
# <!-- Lom&#45;&#45;Vidin -->
# <g id="edge10" class="edge">
# <title>Lom&#45;&#45;Vidin</title>
# <path fill="none" stroke="SteelBlue" d="M48.37,-180.49C43.95,-182.58 38.08,-185.36 33.67,-187.45"/>
# </g>
# <!-- Bjala Slatina -->
# <g id="node2" class="node">
# <title>Bjala Slatina</title>
# <polygon fill="#1f1f1f" stroke="none" points="120.24,-154.8 91.44,-154.8 91.44,-149.76 120.24,-149.76 120.24,-154.8"/>
# <text text-anchor="middle" x="105.84" y="-150.33" font-family="Times,serif" font-size="6.00" fill="White">Bjala Slatina</text>
# </g>
# <!-- Kozloduj -->
# <g id="node20" class="node">
# <title>Kozloduj</title>
# <polygon fill="#1f1f1f" stroke="none" points="103.68,-177.12 74.88,-177.12 74.88,-172.08 103.68,-172.08 103.68,-177.12"/>
# <text text-anchor="middle" x="89.28" y="-172.65" font-family="Times,serif" font-size="6.00" fill="White">Kozloduj</text>
# </g>
# <!-- Bjala Slatina&#45;&#45;Kozloduj -->
# <g id="edge71" class="edge">
# <title>Bjala Slatina&#45;&#45;Kozloduj</title>
# <path fill="none" stroke="SteelBlue" d="M103.81,-155.02C100.63,-159.3 94.52,-167.54 91.33,-171.84"/>
# </g>
# <!-- Kneza -->
# <g id="node64" class="node">
# <title>Kneza</title>
# <polygon fill="#1f1f1f" stroke="none" points="129.6,-156.24 100.8,-156.24 100.8,-151.2 129.6,-151.2 129.6,-156.24"/>
# <text text-anchor="middle" x="115.2" y="-151.77" font-family="Times,serif" font-size="6.00" fill="White">Kneza</text>
# </g>
# <!-- Bjala Slatina&#45;&#45;Kneza -->
# <g id="edge82" class="edge">
# <title>Bjala Slatina&#45;&#45;Kneza</title>
# <path fill="none" stroke="SteelBlue" d="M115.09,-153.7C115.13,-153.71 115.16,-153.71 115.17,-153.72"/>
# </g>
# <!-- Botevgrad -->
# <g id="node3" class="node">
# <title>Botevgrad</title>
# <polygon fill="#1f1f1f" stroke="none" points="107.28,-114.48 78.48,-114.48 78.48,-109.44 107.28,-109.44 107.28,-114.48"/>
# <text text-anchor="middle" x="92.88" y="-110.01" font-family="Times,serif" font-size="6.00" fill="White">Botevgrad</text>
# </g>
# <!-- Etropole -->
# <g id="node45" class="node">
# <title>Etropole</title>
# <polygon fill="#1f1f1f" stroke="none" points="123.84,-108.72 95.04,-108.72 95.04,-103.68 123.84,-103.68 123.84,-108.72"/>
# <text text-anchor="middle" x="109.44" y="-104.25" font-family="Times,serif" font-size="6.00" fill="White">Etropole</text>
# </g>
# <!-- Botevgrad&#45;&#45;Etropole -->
# <g id="edge78" class="edge">
# <title>Botevgrad&#45;&#45;Etropole</title>
# <path fill="none" stroke="SteelBlue" d="M101.55,-108.95C101.67,-108.9 101.8,-108.86 101.92,-108.81"/>
# </g>
# <!-- Mezdra -->
# <g id="node47" class="node">
# <title>Mezdra</title>
# <polygon fill="#1f1f1f" stroke="none" points="102.96,-131.04 74.16,-131.04 74.16,-126 102.96,-126 102.96,-131.04"/>
# <text text-anchor="middle" x="88.56" y="-126.57" font-family="Times,serif" font-size="6.00" fill="White">Mezdra</text>
# </g>
# <!-- Botevgrad&#45;&#45;Mezdra -->
# <g id="edge21" class="edge">
# <title>Botevgrad&#45;&#45;Mezdra</title>
# <path fill="none" stroke="SteelBlue" d="M92.13,-114.84C91.32,-117.96 90.03,-122.87 89.25,-125.89"/>
# </g>
# <!-- Panagjuriste -->
# <g id="node4" class="node">
# <title>Panagjuriste</title>
# <polygon fill="#1f1f1f" stroke="none" points="136.08,-84.96 107.28,-84.96 107.28,-79.92 136.08,-79.92 136.08,-84.96"/>
# <text text-anchor="middle" x="121.68" y="-80.49" font-family="Times,serif" font-size="6.00" fill="White">Panagjuriste</text>
# </g>
# <!-- Pazardzik -->
# <g id="node51" class="node">
# <title>Pazardzik</title>
# <polygon fill="#1f1f1f" stroke="none" points="146.88,-62.64 118.08,-62.64 118.08,-57.6 146.88,-57.6 146.88,-62.64"/>
# <text text-anchor="middle" x="132.48" y="-58.17" font-family="Times,serif" font-size="6.00" fill="White">Pazardzik</text>
# </g>
# <!-- Panagjuriste&#45;&#45;Pazardzik -->
# <g id="edge73" class="edge">
# <title>Panagjuriste&#45;&#45;Pazardzik</title>
# <path fill="none" stroke="SteelBlue" d="M123,-79.7C125.08,-75.42 129.07,-67.18 131.14,-62.88"/>
# </g>
# <!-- Elhovo -->
# <g id="node5" class="node">
# <title>Elhovo</title>
# <polygon fill="#1f1f1f" stroke="none" points="308.16,-60.48 279.36,-60.48 279.36,-55.44 308.16,-55.44 308.16,-60.48"/>
# <text text-anchor="middle" x="293.76" y="-56.01" font-family="Times,serif" font-size="6.00" fill="White">Elhovo</text>
# </g>
# <!-- Jambol -->
# <g id="node50" class="node">
# <title>Jambol</title>
# <polygon fill="#1f1f1f" stroke="none" points="304.56,-84.24 275.76,-84.24 275.76,-79.2 304.56,-79.2 304.56,-84.24"/>
# <text text-anchor="middle" x="290.16" y="-79.77" font-family="Times,serif" font-size="6.00" fill="White">Jambol</text>
# </g>
# <!-- Elhovo&#45;&#45;Jambol -->
# <g id="edge9" class="edge">
# <title>Elhovo&#45;&#45;Jambol</title>
# <path fill="none" stroke="SteelBlue" d="M293.32,-60.87C292.63,-65.43 291.3,-74.21 290.61,-78.78"/>
# </g>
# <!-- Plovdiv -->
# <g id="node6" class="node">
# <title>Plovdiv</title>
# <polygon fill="#1f1f1f" stroke="none" points="177.12,-59.04 148.32,-59.04 148.32,-54 177.12,-54 177.12,-59.04"/>
# <text text-anchor="middle" x="162.72" y="-54.57" font-family="Times,serif" font-size="6.00" fill="White">Plovdiv</text>
# </g>
# <!-- Rakovski -->
# <g id="node34" class="node">
# <title>Rakovski</title>
# <polygon fill="#1f1f1f" stroke="none" points="192.96,-69.12 164.16,-69.12 164.16,-64.08 192.96,-64.08 192.96,-69.12"/>
# <text text-anchor="middle" x="178.56" y="-64.65" font-family="Times,serif" font-size="6.00" fill="White">Rakovski</text>
# </g>
# <!-- Plovdiv&#45;&#45;Rakovski -->
# <g id="edge12" class="edge">
# <title>Plovdiv&#45;&#45;Rakovski</title>
# <path fill="none" stroke="SteelBlue" d="M167.39,-59.49C169.43,-60.79 171.83,-62.31 173.87,-63.62"/>
# </g>
# <!-- Stambolijski -->
# <g id="node61" class="node">
# <title>Stambolijski</title>
# <polygon fill="#1f1f1f" stroke="none" points="162.72,-58.32 133.92,-58.32 133.92,-53.28 162.72,-53.28 162.72,-58.32"/>
# <text text-anchor="middle" x="148.32" y="-53.85" font-family="Times,serif" font-size="6.00" fill="White">Stambolijski</text>
# </g>
# <!-- Plovdiv&#45;&#45;Stambolijski -->
# <g id="edge53" class="edge">
# <title>Plovdiv&#45;&#45;Stambolijski</title>
# <path fill="none" stroke="SteelBlue" d="M148.48,-55.81C148.43,-55.81 148.39,-55.8 148.36,-55.8"/>
# </g>
# <!-- Strazica -->
# <g id="node7" class="node">
# <title>Strazica</title>
# <polygon fill="#1f1f1f" stroke="none" points="264.96,-136.8 236.16,-136.8 236.16,-131.76 264.96,-131.76 264.96,-136.8"/>
# <text text-anchor="middle" x="250.56" y="-132.33" font-family="Times,serif" font-size="6.00" fill="White">Strazica</text>
# </g>
# <!-- Parvomaj -->
# <g id="node8" class="node">
# <title>Parvomaj</title>
# <polygon fill="#1f1f1f" stroke="none" points="210.96,-55.44 182.16,-55.44 182.16,-50.4 210.96,-50.4 210.96,-55.44"/>
# <text text-anchor="middle" x="196.56" y="-50.97" font-family="Times,serif" font-size="6.00" fill="White">Parvomaj</text>
# </g>
# <!-- Dimitrovgrad -->
# <g
